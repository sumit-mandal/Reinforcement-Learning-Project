# %% [markdown]
# ## Importing the dependecies

# %%
# ! pip install tensorflow-gpu==1.15.0 tensorflow==1.15.0 stable-baselines gym-anytrading gym

# %%
# gym stuff
import gym
import gym_anytrading

#Stable baselines
from stable_baselines.common.vec_env import DummyVecEnv #it is a wrapper
from stable_baselines import A2C #A2C is RL algorithm

#processing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %% [markdown]
# ## MarketWatch GME data

# %%
df = pd.read_csv('data/RPOWER.NS.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       250 non-null    float64
#  2   High       250 non-null    float64
#  3   Low        250 non-null    float64
#  4   Close      250 non-null    float64
#  5   Adj Close  250 non-null    float64
#  6   Volume     250 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# # Coverting date to datetimeformat

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   Open       250 non-null    float64
#  2   High       250 non-null    float64
#  3   Low        250 non-null    float64
#  4   Close      250 non-null    float64
#  5   Adj Close  250 non-null    float64
#  6   Volume     250 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 13.9 KB

# %%
# df['Open'] = df['Open'].apply(lambda x: float(x.replace(",","")))

# %%
# df['High'] = df['High'].apply(lambda x: float(x.replace(",","")))

# %%
# df['Low'] = df['Low'].apply(lambda x: float(x.replace(",","")))

# %%
# df['Close'] = df['Close'].apply(lambda x: float(x.replace(",","")))

# %%
#Sorting the data from oldest to newest
df.sort_values('Date',ascending=True,inplace=True)
df.head()
# Out:
#         Date  Open  High   Low  Close  Adj Close     Volume
# 0 2020-06-18  3.00  3.00  3.00   3.00       3.00  2031776.0
# 1 2020-06-19  3.15  3.15  3.15   3.15       3.15  1257695.0
# 2 2020-06-22  3.30  3.30  3.30   3.30       3.30  1435136.0
# 3 2020-06-23  3.45  3.45  3.45   3.45       3.45  5144728.0
# 4 2020-06-24  3.60  3.60  3.60   3.60       3.60  3705614.0

# %%
# Set index as date
df.set_index('Date',inplace=True)
df.head()
# Out:
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2020-06-18  3.00  3.00  3.00   3.00       3.00  2031776.0
# 2020-06-19  3.15  3.15  3.15   3.15       3.15  1257695.0
# 2020-06-22  3.30  3.30  3.30   3.30       3.30  1435136.0
# 2020-06-23  3.45  3.45  3.45   3.45       3.45  5144728.0
# 2020-06-24  3.60  3.60  3.60   3.60       3.60  3705614.0

# %%
env = gym.make('stocks-v0',df=df,frame_bound=(5,250),window_size=5)
#window_size = how many previous timestep data our bot is going to have for referce to make a trade
#frame_bound = specifies how much data we want to pass through our environment we are gonna start at 5th time step 
#and go all the way to the hundredth time_step .

# %% [markdown]
# `Note since our window size is 5 and frame_bound's initial value is also 5 our env.prices will start from very first day i.e. 05/25/2021`
#
# `And if our frame bound's initial value is changed to (10,100) from (5,100) our env.prices will start from 5 day later i.e. 05/18/2021`

# %%
print("(env.prices\n",env.prices)
print("env.signal_features\n",env.signal_features) #it shows price and change in price from previous timestep
# Out:
# (env.prices
#  [ 3.    3.15  3.3   3.45  3.6   3.75  3.9   4.05  4.25  4.45  4.65  4.45
#   4.25  4.05  3.85  4.    3.9   3.75  3.6   3.45  3.3   3.45  3.6   3.75
#   3.65  3.7   3.7   3.55  3.4   3.55  3.4   3.3   3.45  3.35  3.45  3.45
#   3.45  3.75  4.05  3.85  3.8   3.75  3.8   3.75  3.9   3.85  3.8   3.7
#   3.65  3.6   3.7   3.65  3.4   3.25  3.35  3.3   3.3   3.2   3.25  3.2
#   3.15  3.1   3.05  3.05  3.    2.9   3.    2.75  2.7   2.7   2.65  2.9
#   2.85  2.85  2.75  2.7   2.75  2.8   2.65  2.7   2.75  2.7   2.65  2.65
#   2.5   2.55  2.55  2.45  2.45  2.75  3.3   3.35  3.05  3.    3.5   3.5
#   3.25  3.15  3.2   3.05  3.1   3.1   3.05  3.    3.05  3.05   nan  3.1
#   3.05  3.    3.    3.15  3.3   3.35  3.2   3.1   3.1   3.05  3.2   3.35
#   3.5   3.65  3.8   3.8   3.95  4.1   3.9   3.75  3.6   3.6   3.45  3.3
#   3.45  3.6   3.5   3.45  3.4   3.4   3.5   3.65  3.8   3.7   3.65  3.6
#   3.55  3.45  3.4   3.4   3.5   3.45  3.45  3.5   3.5   3.4   3.35  3.2
#   3.2   3.3   3.25  3.25  3.3   3.35  3.35  3.6   3.5   3.3   3.25  3.2
#   3.25  3.2   3.2   3.25  3.1   3.4   3.7   3.55  3.9   4.25  4.45  4.5
#   4.3   4.5   4.7   4.9   5.1   5.35  5.2   5.2   4.95  4.75  4.55  4.35
#   4.55  4.75  4.9   4.7   4.7   4.55  4.35  4.55  4.75  4.95  4.85  4.9
#   4.8   4.35  4.5   4.4   4.7   4.45  4.55  4.5   4.5   4.45  4.45  4.55
#   4.65  4.85  5.3   5.05  5.1   5.5   6.05  6.65  7.3   6.95  6.8   6.6
#   6.9   7.    6.9   7.15  7.5   7.85  8.2   8.6   8.25  8.65  8.65  9.05
#   9.5   9.95 10.4  10.9  11.4  11.95 12.5  13.1  13.75   nan]
# env.signal_features
#  [[ 3.    0.  ]
#  [ 3.15  0.15]
#  [ 3.3   0.15]
#  [ 3.45  0.15]
#  [ 3.6   0.15]
#  [ 3.75  0.15]
#  [ 3.9   0.15]
#  [ 4.05  0.15]
#  [ 4.25  0.2 ]
#  [ 4.45  0.2 ]
#  [ 4.65  0.2 ]
#  [ 4.45 -0.2 ]
#  [ 4.25 -0.2 ]
#  [ 4.05 -0.2 ]
#  [ 3.85 -0.2 ]
#  [ 4.    0.15]
#  [ 3.9  -0.1 ]
#  [ 3.75 -0.15]
#  [ 3.6  -0.15]
#  [ 3.45 -0.15]
#  [ 3.3  -0.15]
#  [ 3.45  0.15]
#  [ 3.6   0.15]
#  [ 3.75  0.15]
#  [ 3.65 -0.1 ]
#  [ 3.7   0.05]
#  [ 3.7   0.  ]
#  [ 3.55 -0.15]
#  [ 3.4  -0.15]
#  [ 3.55  0.15]
#  [ 3.4  -0.15]
#  [ 3.3  -0.1 ]
#  [ 3.45  0.15]
#  [ 3.35 -0.1 ]
#  [ 3.45  0.1 ]
#  [ 3.45  0.  ]
#  [ 3.45  0.  ]
#  [ 3.75  0.3 ]
#  [ 4.05  0.3 ]
#  [ 3.85 -0.2 ]
#  [ 3.8  -0.05]
#  [ 3.75 -0.05]
#  [ 3.8   0.05]
#  [ 3.75 -0.05]
#  [ 3.9   0.15]
#  [ 3.85 -0.05]
#  [ 3.8  -0.05]
#  [ 3.7  -0.1 ]
#  [ 3.65 -0.05]
#  [ 3.6  -0.05]
#  [ 3.7   0.1 ]
#  [ 3.65 -0.05]
#  [ 3.4  -0.25]
#  [ 3.25 -0.15]
#  [ 3.35  0.1 ]
#  [ 3.3  -0.05]
#  [ 3.3   0.  ]
#  [ 3.2  -0.1 ]
#  [ 3.25  0.05]
#  [ 3.2  -0.05]
#  [ 3.15 -0.05]
#  [ 3.1  -0.05]
#  [ 3.05 -0.05]
#  [ 3.05  0.  ]
#  [ 3.   -0.05]
#  [ 2.9  -0.1 ]
#  [ 3.    0.1 ]
#  [ 2.75 -0.25]
#  [ 2.7  -0.05]
#  [ 2.7   0.  ]
#  [ 2.65 -0.05]
#  [ 2.9   0.25]
#  [ 2.85 -0.05]
#  [ 2.85  0.  ]
#  [ 2.75 -0.1 ]
#  [ 2.7  -0.05]
#  [ 2.75  0.05]
#  [ 2.8   0.05]
#  [ 2.65 -0.15]
#  [ 2.7   0.05]
#  [ 2.75  0.05]
#  [ 2.7  -0.05]
#  [ 2.65 -0.05]
#  [ 2.65  0.  ]
#  [ 2.5  -0.15]
#  [ 2.55  0.05]
#  [ 2.55  0.  ]
#  [ 2.45 -0.1 ]
#  [ 2.45  0.  ]
#  [ 2.75  0.3 ]
#  [ 3.3   0.55]
#  [ 3.35  0.05]
#  [ 3.05 -0.3 ]
#  [ 3.   -0.05]
#  [ 3.5   0.5 ]
#  [ 3.5   0.  ]
#  [ 3.25 -0.25]
#  [ 3.15 -0.1 ]
#  [ 3.2   0.05]
#  [ 3.05 -0.15]
#  [ 3.1   0.05]
#  [ 3.1   0.  ]
#  [ 3.05 -0.05]
#  [ 3.   -0.05]
#  [ 3.05  0.05]
#  [ 3.05  0.  ]
#  [  nan   nan]
#  [ 3.1    nan]
#  [ 3.05 -0.05]
#  [ 3.   -0.05]
#  [ 3.    0.  ]
#  [ 3.15  0.15]
#  [ 3.3   0.15]
#  [ 3.35  0.05]
#  [ 3.2  -0.15]
#  [ 3.1  -0.1 ]
#  [ 3.1   0.  ]
#  [ 3.05 -0.05]
#  [ 3.2   0.15]
#  [ 3.35  0.15]
#  [ 3.5   0.15]
#  [ 3.65  0.15]
#  [ 3.8   0.15]
#  [ 3.8   0.  ]
#  [ 3.95  0.15]
#  [ 4.1   0.15]
#  [ 3.9  -0.2 ]
#  [ 3.75 -0.15]
#  [ 3.6  -0.15]
#  [ 3.6   0.  ]
#  [ 3.45 -0.15]
#  [ 3.3  -0.15]
#  [ 3.45  0.15]
#  [ 3.6   0.15]
#  [ 3.5  -0.1 ]
#  [ 3.45 -0.05]
#  [ 3.4  -0.05]
#  [ 3.4   0.  ]
#  [ 3.5   0.1 ]
#  [ 3.65  0.15]
#  [ 3.8   0.15]
#  [ 3.7  -0.1 ]
#  [ 3.65 -0.05]
#  [ 3.6  -0.05]
#  [ 3.55 -0.05]
#  [ 3.45 -0.1 ]
#  [ 3.4  -0.05]
#  [ 3.4   0.  ]
#  [ 3.5   0.1 ]
#  [ 3.45 -0.05]
#  [ 3.45  0.  ]
#  [ 3.5   0.05]
#  [ 3.5   0.  ]
#  [ 3.4  -0.1 ]
#  [ 3.35 -0.05]
#  [ 3.2  -0.15]
#  [ 3.2   0.  ]
#  [ 3.3   0.1 ]
#  [ 3.25 -0.05]
#  [ 3.25  0.  ]
#  [ 3.3   0.05]
#  [ 3.35  0.05]
#  [ 3.35  0.  ]
#  [ 3.6   0.25]
#  [ 3.5  -0.1 ]
#  [ 3.3  -0.2 ]
#  [ 3.25 -0.05]
#  [ 3.2  -0.05]
#  [ 3.25  0.05]
#  [ 3.2  -0.05]
#  [ 3.2   0.  ]
#  [ 3.25  0.05]
#  [ 3.1  -0.15]
#  [ 3.4   0.3 ]
#  [ 3.7   0.3 ]
#  [ 3.55 -0.15]
#  [ 3.9   0.35]
#  [ 4.25  0.35]
#  [ 4.45  0.2 ]
#  [ 4.5   0.05]
#  [ 4.3  -0.2 ]
#  [ 4.5   0.2 ]
#  [ 4.7   0.2 ]
#  [ 4.9   0.2 ]
#  [ 5.1   0.2 ]
#  [ 5.35  0.25]
#  [ 5.2  -0.15]
#  [ 5.2   0.  ]
#  [ 4.95 -0.25]
#  [ 4.75 -0.2 ]
#  [ 4.55 -0.2 ]
#  [ 4.35 -0.2 ]
#  [ 4.55  0.2 ]
#  [ 4.75  0.2 ]
#  [ 4.9   0.15]
#  [ 4.7  -0.2 ]
#  [ 4.7   0.  ]
#  [ 4.55 -0.15]
#  [ 4.35 -0.2 ]
#  [ 4.55  0.2 ]
#  [ 4.75  0.2 ]
#  [ 4.95  0.2 ]
#  [ 4.85 -0.1 ]
#  [ 4.9   0.05]
#  [ 4.8  -0.1 ]
#  [ 4.35 -0.45]
#  [ 4.5   0.15]
#  [ 4.4  -0.1 ]
#  [ 4.7   0.3 ]
#  [ 4.45 -0.25]
#  [ 4.55  0.1 ]
#  [ 4.5  -0.05]
#  [ 4.5   0.  ]
#  [ 4.45 -0.05]
#  [ 4.45  0.  ]
#  [ 4.55  0.1 ]
#  [ 4.65  0.1 ]
#  [ 4.85  0.2 ]
#  [ 5.3   0.45]
#  [ 5.05 -0.25]
#  [ 5.1   0.05]
#  [ 5.5   0.4 ]
#  [ 6.05  0.55]
#  [ 6.65  0.6 ]
#  [ 7.3   0.65]
#  [ 6.95 -0.35]
#  [ 6.8  -0.15]
#  [ 6.6  -0.2 ]
#  [ 6.9   0.3 ]
#  [ 7.    0.1 ]
#  [ 6.9  -0.1 ]
#  [ 7.15  0.25]
#  [ 7.5   0.35]
#  [ 7.85  0.35]
#  [ 8.2   0.35]
#  [ 8.6   0.4 ]
#  [ 8.25 -0.35]
#  [ 8.65  0.4 ]
#  [ 8.65  0.  ]
#  [ 9.05  0.4 ]
#  [ 9.5   0.45]
#  [ 9.95  0.45]
#  [10.4   0.45]
#  [10.9   0.5 ]
#  [11.4   0.5 ]
#  [11.95  0.55]
#  [12.5   0.55]
#  [13.1   0.6 ]
#  [13.75  0.65]
#  [  nan   nan]]

# %% [markdown]
# ## Build Environment

# %%
#Taking random steps/ Testing the env
state = env.reset() #it allows us to get initial state
while True:
    action = env.action_space.sample() #looping through each index and taking random action
    n_state,reward,done,info = env.step(action) #applying action to our environment. and storing them in variables
    if done: 
        print(f" n_state\n{n_state}\n reward\n{reward}\n  done\n{done}\n  info\n{info}\n ")
        
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
#  n_state
# [[11.4   0.5 ]
#  [11.95  0.55]
#  [12.5   0.55]
#  [13.1   0.6 ]
#  [13.75  0.65]]
#  reward
# 0
#   done
# True
#   info
# {'total_reward': nan, 'total_profit': nan, 'position': 0}

# %%
env.action_space #we have only 2 action buy and sell
# Out:
# Discrete(2)

# %% [markdown]
# # 3.1 - Add Custom Indicators

# %% [markdown]
# ### 3.1.1 Install and Import New Dependencies
#
# ##### `We'll  be using finta`

# %%
# !pip install finta
from gym_anytrading.envs import StocksEnv
from finta import TA #Technical Analysis lirary

# %% [markdown]
# ### 3.1.2 - Fix Volume Column

# %%
# print(df.dtypes)
# #inintially volume is object/string changing it to float
# df['Volume'] = df['Volume'].apply(lambda x: float(x.replace(",","")))

# # (x.replace",","") stripping/removing all the commas

# %% [markdown]
# ### 3.1.3 Calculate SMA,RSI and OBV

# %%
df['SMA'] = TA.SMA(df,12) #we want 12 period simple movimg average
df['RSI'] = TA.RSI(df) #relative strength index
df['OBV'] = TA.OBV(df) #on balance volume inndicator

df.fillna(0,inplace=True) #removing NAN with 0

# %%
df.head(15)
# Out:
#             Open  High   Low  Close  Adj Close       Volume       SMA  \
# Date
# 2020-06-18  3.00  3.00  3.00   3.00       3.00    2031776.0  0.000000
# 2020-06-19  3.15  3.15  3.15   3.15       3.15    1257695.0  0.000000
# 2020-06-22  3.30  3.30  3.30   3.30       3.30    1435136.0  0.000000
# 2020-06-23  3.45  3.45  3.45   3.45       3.45    5144728.0  0.000000
# 2020-06-24  3.60  3.60  3.60   3.60       3.60    3705614.0  0.000000
# 2020-06-25  3.75  3.75  3.75   3.75       3.75    1724830.0  0.000000
# 2020-06-26  3.90  3.90  3.90   3.90       3.90     842895.0  0.000000
# 2020-06-29  4.05  4.05  4.05   4.05       4.05    1772642.0  0.000000
# 2020-06-30  4.25  4.25  4.25   4.25       4.25    4183513.0  0.000000
# 2020-07-01  4.45  4.45  4.05   4.45       4.45   83313787.0  0.000000
# 2020-07-02  4.65  4.65  4.65   4.65       4.65    1632832.0  0.000000
# 2020-07-03  4.85  4.85  4.45   4.45       4.45  124038117.0  3.833333
# 2020-07-06  4.25  4.25  4.25   4.25       4.25    8226636.0  3.937500
# 2020-07-07  4.05  4.05  4.05   4.05       4.05    4035243.0  4.012500
# 2020-07-08  3.85  3.85  3.85   3.85       3.85    4545132.0  4.058333
#
#                    RSI          OBV
# Date
# 2020-06-18    0.000000          0.0
# 2020-06-19  100.000000    1257695.0
# 2020-06-22  100.000000    2692831.0
# 2020-06-23  100.000000    7837559.0
# 2020-06-24  100.000000   11543173.0
# 2020-06-25  100.000000   13268003.0
# 2020-06-26  100.000000   14110898.0
# 2020-06-29  100.000000   15883540.0
# 2020-06-30  100.000000   20067053.0
# 2020-07-01  100.000000  103380840.0
# 2020-07-02  100.000000  105013672.0
# 2020-07-03   85.187440  -19024445.0
# 2020-07-06   73.467856  -27251081.0
# 2020-07-07   63.987656  -31286324.0
# 2020-07-08   56.180539  -35831456.0

# %% [markdown]
# #### 3.1.4 Create New Environment

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size #here env.frame_bound[0] = 5
    end = env.frame_bound[1] # here env.frame_bound[1] = 250
    prices = env.df.loc[:,'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:,['Low','Volume','SMA','RSI','OBV']].to_numpy()[start:end] 
    return prices,signal_features

# %%
#Creating custom env
class MyCustomEnv(StocksEnv): #inheritence is happening here
    _process_data = add_signals
    
env2 = MyCustomEnv(df=df,window_size=12,frame_bound=(12,50)) #creating instance

# %%
env2.prices
# Out:
# array([3.  , 3.15, 3.3 , 3.45, 3.6 , 3.75, 3.9 , 4.05, 4.25, 4.05, 4.65,
#        4.45, 4.25, 4.05, 3.85, 3.7 , 3.8 , 3.75, 3.6 , 3.45, 3.3 , 3.15,
#        3.5 , 3.65, 3.6 , 3.6 , 3.6 , 3.55, 3.4 , 3.3 , 3.4 , 3.25, 3.3 ,
#        3.3 , 3.35, 3.35, 3.35, 3.4 , 3.8 , 3.75, 3.7 , 3.7 , 3.75, 3.75,
#        3.7 , 3.75, 3.75, 3.6 , 3.6 , 3.55])

# %%
df.head()
# Out:
#             Open  High   Low  Close  Adj Close     Volume  SMA    RSI  \
# Date
# 2020-06-18  3.00  3.00  3.00   3.00       3.00  2031776.0  0.0    0.0
# 2020-06-19  3.15  3.15  3.15   3.15       3.15  1257695.0  0.0  100.0
# 2020-06-22  3.30  3.30  3.30   3.30       3.30  1435136.0  0.0  100.0
# 2020-06-23  3.45  3.45  3.45   3.45       3.45  5144728.0  0.0  100.0
# 2020-06-24  3.60  3.60  3.60   3.60       3.60  3705614.0  0.0  100.0
#
#                    OBV
# Date
# 2020-06-18         0.0
# 2020-06-19   1257695.0
# 2020-06-22   2692831.0
# 2020-06-23   7837559.0
# 2020-06-24  11543173.0

# %%
env2.signal_features
# Out:
# array([[ 3.00000000e+00,  2.03177600e+06,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 3.15000000e+00,  1.25769500e+06,  0.00000000e+00,
#          1.00000000e+02,  1.25769500e+06],
#        [ 3.30000000e+00,  1.43513600e+06,  0.00000000e+00,
#          1.00000000e+02,  2.69283100e+06],
#        [ 3.45000000e+00,  5.14472800e+06,  0.00000000e+00,
#          1.00000000e+02,  7.83755900e+06],
#        [ 3.60000000e+00,  3.70561400e+06,  0.00000000e+00,
#          1.00000000e+02,  1.15431730e+07],
#        [ 3.75000000e+00,  1.72483000e+06,  0.00000000e+00,
#          1.00000000e+02,  1.32680030e+07],
#        [ 3.90000000e+00,  8.42895000e+05,  0.00000000e+00,
#          1.00000000e+02,  1.41108980e+07],
#        [ 4.05000000e+00,  1.77264200e+06,  0.00000000e+00,
#          1.00000000e+02,  1.58835400e+07],
#        [ 4.25000000e+00,  4.18351300e+06,  0.00000000e+00,
#          1.00000000e+02,  2.00670530e+07],
#        [ 4.05000000e+00,  8.33137870e+07,  0.00000000e+00,
#          1.00000000e+02,  1.03380840e+08],
#        [ 4.65000000e+00,  1.63283200e+06,  0.00000000e+00,
#          1.00000000e+02,  1.05013672e+08],
#        [ 4.45000000e+00,  1.24038117e+08,  3.83333333e+00,
#          8.51874398e+01, -1.90244450e+07],
#        [ 4.25000000e+00,  8.22663600e+06,  3.93750000e+00,
#          7.34678562e+01, -2.72510810e+07],
#        [ 4.05000000e+00,  4.03524300e+06,  4.01250000e+00,
#          6.39876562e+01, -3.12863240e+07],
#        [ 3.85000000e+00,  4.54513200e+06,  4.05833333e+00,
#          5.61805387e+01, -3.58314560e+07],
#        [ 3.70000000e+00,  1.33160880e+08,  4.10416667e+00,
#          6.01114126e+01,  9.73294240e+07],
#        [ 3.80000000e+00,  8.15083830e+07,  4.12916667e+00,
#          5.64742244e+01,  1.58210410e+07],
#        [ 3.75000000e+00,  3.32516000e+07,  4.12916667e+00,
#          5.14457706e+01, -1.74305590e+07],
#        [ 3.60000000e+00,  4.46898100e+06,  4.10416667e+00,
#          4.69443253e+01, -2.18995400e+07],
#        [ 3.45000000e+00,  9.29152260e+07,  4.05416667e+00,
#          4.29017171e+01, -1.14814766e+08],
#        [ 3.30000000e+00,  1.75569460e+07,  3.97500000e+00,
#          3.92607110e+01, -1.32371712e+08],
#        [ 3.15000000e+00,  3.65307440e+07,  3.89166667e+00,
#          4.43472034e+01, -9.58409680e+07],
#        [ 3.50000000e+00,  7.75270100e+06,  3.80416667e+00,
#          4.89510437e+01, -8.80882670e+07],
#        [ 3.65000000e+00,  2.07059740e+07,  3.74583333e+00,
#          5.31268653e+01, -6.73822930e+07],
#        [ 3.60000000e+00,  3.63767080e+07,  3.69583333e+00,
#          5.01798791e+01, -1.03759001e+08],
#        [ 3.60000000e+00,  1.96231060e+07,  3.66666667e+00,
#          5.16247913e+01, -8.41358950e+07],
#        [ 3.60000000e+00,  2.74561060e+07,  3.65416667e+00,
#          5.16247913e+01,  0.00000000e+00],
#        [ 3.55000000e+00,  1.15209380e+07,  3.61666667e+00,
#          4.68929036e+01, -9.56568330e+07],
#        [ 3.40000000e+00,  2.05936190e+07,  3.57500000e+00,
#          4.26799675e+01, -1.16250452e+08],
#        [ 3.30000000e+00,  2.82890870e+07,  3.55833333e+00,
#          4.77365862e+01, -8.79613650e+07],
#        [ 3.40000000e+00,  2.19320210e+07,  3.54166667e+00,
#          4.35949265e+01, -1.09893386e+08],
#        [ 3.25000000e+00,  2.19441780e+07,  3.52916667e+00,
#          4.10386405e+01, -1.31837564e+08],
#        [ 3.30000000e+00,  3.28287350e+07,  3.54166667e+00,
#          4.61403204e+01, -9.90088290e+07],
#        [ 3.30000000e+00,  1.65969460e+07,  3.53333333e+00,
#          4.34416757e+01, -1.15605775e+08],
#        [ 3.35000000e+00,  1.95922430e+07,  3.52083333e+00,
#          4.67930152e+01, -9.60135320e+07],
#        [ 3.35000000e+00,  1.21624190e+07,  3.49583333e+00,
#          4.67930152e+01,  0.00000000e+00],
#        [ 3.35000000e+00,  1.20808710e+07,  3.47916667e+00,
#          4.67930152e+01,  0.00000000e+00],
#        [ 3.40000000e+00,  2.25088070e+07,  3.48333333e+00,
#          5.64599016e+01, -7.35047250e+07],
#        [ 3.80000000e+00,  5.91504880e+07,  3.51250000e+00,
#          6.35848915e+01, -1.43542370e+07],
#        [ 3.75000000e+00,  3.50925080e+07,  3.53750000e+00,
#          5.68999149e+01, -4.94467450e+07],
#        [ 3.70000000e+00,  1.87654690e+07,  3.57083333e+00,
#          5.53336684e+01, -6.82122140e+07],
#        [ 3.70000000e+00,  2.47697220e+07,  3.58750000e+00,
#          5.37405955e+01, -9.29819360e+07],
#        [ 3.75000000e+00,  1.81821250e+07,  3.62083333e+00,
#          5.51317334e+01, -7.47998110e+07],
#        [ 3.75000000e+00,  9.04336000e+06,  3.65833333e+00,
#          5.34022578e+01, -8.38431710e+07],
#        [ 3.70000000e+00,  5.42474630e+07,  3.69583333e+00,
#          5.76902965e+01, -2.95957080e+07],
#        [ 3.75000000e+00,  2.36447840e+07,  3.73750000e+00,
#          5.58455125e+01, -5.32404920e+07],
#        [ 3.75000000e+00,  1.63718230e+07,  3.76666667e+00,
#          5.39863746e+01, -6.96123150e+07],
#        [ 3.60000000e+00,  1.49901390e+07,  3.78750000e+00,
#          5.03743751e+01, -8.46024540e+07],
#        [ 3.60000000e+00,  1.35473180e+07,  3.80416667e+00,
#          4.86226855e+01, -9.81497720e+07],
#        [ 3.55000000e+00,  2.32397460e+07,  3.79166667e+00,
#          4.68675743e+01, -1.21389518e+08]])

# %% [markdown]
# ## Building Environment and Training

# %%
#Wrapping our environment inside of dummyvenEnv
env_maker = lambda:env2
# env_maker = lambda:gym.make('stocks-v0',df=df, frame_bound=(5,100),window_size=5)

env  = DummyVecEnv([env_maker])

#we are creatinng env_makr function and putting it inside DummyvecEnv wrapper

# %%
#Start Training
model = A2C('MlpLstmPolicy',env,verbose=1) #multilayer-perceptron -lstm policy
model.learn(total_timesteps=100000) #starting to learn
# Out:
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\policies.py:420: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | -0.231   |
# | fps                | 2        |
# | nupdates           | 1        |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 5        |
# | value_loss         | 0.0145   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.8e+03 |
# | fps                | 73       |
# | nupdates           | 100      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 500      |
# | value_loss         | 0.00162  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.33    |
# | fps                | 89       |
# | nupdates           | 200      |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1000     |
# | value_loss         | 0.00319  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.1     |
# | fps                | 95       |
# | nupdates           | 300      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1500     |
# | value_loss         | 0.0119   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -12.1    |
# | fps                | 98       |
# | nupdates           | 400      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 2000     |
# | value_loss         | 0.00249  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.587   |
# | fps                | 99       |
# | nupdates           | 500      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 2500     |
# | value_loss         | 0.00765  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.52    |
# | fps                | 101      |
# | nupdates           | 600      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 3000     |
# | value_loss         | 0.00135  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -442     |
# | fps                | 101      |
# | nupdates           | 700      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 3500     |
# | value_loss         | 0.0097   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.83    |
# | fps                | 102      |
# | nupdates           | 800      |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 4000     |
# | value_loss         | 0.00393  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.356    |
# | fps                | 101      |
# | nupdates           | 900      |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 4500     |
# | value_loss         | 0.00252  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -270     |
# | fps                | 99       |
# | nupdates           | 1000     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 5000     |
# | value_loss         | 0.00289  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.39    |
# | fps                | 97       |
# | nupdates           | 1100     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 5500     |
# | value_loss         | 0.0082   |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.31e+03 |
# | fps                | 96        |
# | nupdates           | 1200      |
# | policy_entropy     | 0.665     |
# | total_timesteps    | 6000      |
# | value_loss         | 0.00265   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.058    |
# | fps                | 96       |
# | nupdates           | 1300     |
# | policy_entropy     | 0.664    |
# | total_timesteps    | 6500     |
# | value_loss         | 0.00198  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.854    |
# | fps                | 96       |
# | nupdates           | 1400     |
# | policy_entropy     | 0.635    |
# | total_timesteps    | 7000     |
# | value_loss         | 0.00077  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.36    |
# | fps                | 96       |
# | nupdates           | 1500     |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 7500     |
# | value_loss         | 0.106    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.123    |
# | fps                | 96       |
# | nupdates           | 1600     |
# | policy_entropy     | 0.64     |
# | total_timesteps    | 8000     |
# | value_loss         | 0.000837 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.422    |
# | fps                | 95       |
# | nupdates           | 1700     |
# | policy_entropy     | 0.636    |
# | total_timesteps    | 8500     |
# | value_loss         | 0.0523   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.491    |
# | fps                | 96       |
# | nupdates           | 1800     |
# | policy_entropy     | 0.484    |
# | total_timesteps    | 9000     |
# | value_loss         | 0.0436   |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.52e+04 |
# | fps                | 95        |
# | nupdates           | 1900      |
# | policy_entropy     | 0.508     |
# | total_timesteps    | 9500      |
# | value_loss         | 0.0141    |
# ----------------------------------
# ---------------------------------
# | explained_variance | -48.4    |
# | fps                | 95       |
# | nupdates           | 2000     |
# | policy_entropy     | 0.367    |
# | total_timesteps    | 10000    |
# | value_loss         | 0.00283  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.565    |
# | fps                | 95       |
# | nupdates           | 2100     |
# | policy_entropy     | 0.54     |
# | total_timesteps    | 10500    |
# | value_loss         | 0.0441   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.248    |
# | fps                | 95       |
# | nupdates           | 2200     |
# | policy_entropy     | 0.348    |
# | total_timesteps    | 11000    |
# | value_loss         | 0.0495   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.846    |
# | fps                | 95       |
# | nupdates           | 2300     |
# | policy_entropy     | 0.548    |
# | total_timesteps    | 11500    |
# | value_loss         | 0.00475  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.667    |
# | fps                | 95       |
# | nupdates           | 2400     |
# | policy_entropy     | 0.264    |
# | total_timesteps    | 12000    |
# | value_loss         | 0.022    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.32    |
# | fps                | 95       |
# | nupdates           | 2500     |
# | policy_entropy     | 0.46     |
# | total_timesteps    | 12500    |
# | value_loss         | 0.00309  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.765    |
# | fps                | 95       |
# | nupdates           | 2600     |
# | policy_entropy     | 0.272    |
# | total_timesteps    | 13000    |
# | value_loss         | 0.0147   |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e+03 |
# | fps                | 95        |
# | nupdates           | 2700      |
# | policy_entropy     | 0.574     |
# | total_timesteps    | 13500     |
# | value_loss         | 0.00815   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.242    |
# | fps                | 95       |
# | nupdates           | 2800     |
# | policy_entropy     | 0.325    |
# | total_timesteps    | 14000    |
# | value_loss         | 0.0214   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -340     |
# | fps                | 95       |
# | nupdates           | 2900     |
# | policy_entropy     | 0.547    |
# | total_timesteps    | 14500    |
# | value_loss         | 0.0023   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -359     |
# | fps                | 94       |
# | nupdates           | 3000     |
# | policy_entropy     | 0.191    |
# | total_timesteps    | 15000    |
# | value_loss         | 0.0212   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.698    |
# | fps                | 94       |
# | nupdates           | 3100     |
# | policy_entropy     | 0.522    |
# | total_timesteps    | 15500    |
# | value_loss         | 0.000422 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.91    |
# | fps                | 93       |
# | nupdates           | 3200     |
# | policy_entropy     | 0.265    |
# | total_timesteps    | 16000    |
# | value_loss         | 0.0513   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.653    |
# | fps                | 93       |
# | nupdates           | 3300     |
# | policy_entropy     | 0.498    |
# | total_timesteps    | 16500    |
# | value_loss         | 0.00112  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -19.3    |
# | fps                | 92       |
# | nupdates           | 3400     |
# | policy_entropy     | 0.288    |
# | total_timesteps    | 17000    |
# | value_loss         | 0.00109  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.212    |
# | fps                | 92       |
# | nupdates           | 3500     |
# | policy_entropy     | 0.501    |
# | total_timesteps    | 17500    |
# | value_loss         | 0.00119  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -20.1    |
# | fps                | 91       |
# | nupdates           | 3600     |
# | policy_entropy     | 0.159    |
# | total_timesteps    | 18000    |
# | value_loss         | 0.0018   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.827    |
# | fps                | 91       |
# | nupdates           | 3700     |
# | policy_entropy     | 0.164    |
# | total_timesteps    | 18500    |
# | value_loss         | 0.000593 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.337    |
# | fps                | 91       |
# | nupdates           | 3800     |
# | policy_entropy     | 0.198    |
# | total_timesteps    | 19000    |
# | value_loss         | 0.00205  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 91       |
# | nupdates           | 3900     |
# | policy_entropy     | 0.374    |
# | total_timesteps    | 19500    |
# | value_loss         | 0.00331  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.489    |
# | fps                | 90       |
# | nupdates           | 4000     |
# | policy_entropy     | 0.276    |
# | total_timesteps    | 20000    |
# | value_loss         | 0.00285  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 90       |
# | nupdates           | 4100     |
# | policy_entropy     | 0.343    |
# | total_timesteps    | 20500    |
# | value_loss         | 0.00126  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.808    |
# | fps                | 90       |
# | nupdates           | 4200     |
# | policy_entropy     | 0.342    |
# | total_timesteps    | 21000    |
# | value_loss         | 0.00374  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 90       |
# | nupdates           | 4300     |
# | policy_entropy     | 0.193    |
# | total_timesteps    | 21500    |
# | value_loss         | 0.000356 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.478    |
# | fps                | 89       |
# | nupdates           | 4400     |
# | policy_entropy     | 0.397    |
# | total_timesteps    | 22000    |
# | value_loss         | 0.00117  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 89       |
# | nupdates           | 4500     |
# | policy_entropy     | 0.139    |
# | total_timesteps    | 22500    |
# | value_loss         | 0.012    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.659    |
# | fps                | 89       |
# | nupdates           | 4600     |
# | policy_entropy     | 0.492    |
# | total_timesteps    | 23000    |
# | value_loss         | 0.000623 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.27    |
# | fps                | 89       |
# | nupdates           | 4700     |
# | policy_entropy     | 0.0847   |
# | total_timesteps    | 23500    |
# | value_loss         | 0.00149  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.169    |
# | fps                | 89       |
# | nupdates           | 4800     |
# | policy_entropy     | 0.577    |
# | total_timesteps    | 24000    |
# | value_loss         | 0.00237  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 89       |
# | nupdates           | 4900     |
# | policy_entropy     | 0.102    |
# | total_timesteps    | 24500    |
# | value_loss         | 0.0004   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.705    |
# | fps                | 89       |
# | nupdates           | 5000     |
# | policy_entropy     | 0.468    |
# | total_timesteps    | 25000    |
# | value_loss         | 0.000666 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.854    |
# | fps                | 89       |
# | nupdates           | 5100     |
# | policy_entropy     | 0.0648   |
# | total_timesteps    | 25500    |
# | value_loss         | 0.0012   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.855    |
# | fps                | 89       |
# | nupdates           | 5200     |
# | policy_entropy     | 0.361    |
# | total_timesteps    | 26000    |
# | value_loss         | 0.00222  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.952    |
# | fps                | 90       |
# | nupdates           | 5300     |
# | policy_entropy     | 0.0512   |
# | total_timesteps    | 26500    |
# | value_loss         | 5e-05    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 90       |
# | nupdates           | 5400     |
# | policy_entropy     | 0.296    |
# | total_timesteps    | 27000    |
# | value_loss         | 0.000207 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.843    |
# | fps                | 90       |
# | nupdates           | 5500     |
# | policy_entropy     | 0.0147   |
# | total_timesteps    | 27500    |
# | value_loss         | 0.000113 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 91       |
# | nupdates           | 5600     |
# | policy_entropy     | 0.292    |
# | total_timesteps    | 28000    |
# | value_loss         | 0.000252 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.771    |
# | fps                | 91       |
# | nupdates           | 5700     |
# | policy_entropy     | 0.0448   |
# | total_timesteps    | 28500    |
# | value_loss         | 8.49e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 91       |
# | nupdates           | 5800     |
# | policy_entropy     | 0.22     |
# | total_timesteps    | 29000    |
# | value_loss         | 0.000625 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.906    |
# | fps                | 91       |
# | nupdates           | 5900     |
# | policy_entropy     | 0.0538   |
# | total_timesteps    | 29500    |
# | value_loss         | 3.41e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 92       |
# | nupdates           | 6000     |
# | policy_entropy     | 0.354    |
# | total_timesteps    | 30000    |
# | value_loss         | 0.000841 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.983    |
# | fps                | 92       |
# | nupdates           | 6100     |
# | policy_entropy     | 0.0759   |
# | total_timesteps    | 30500    |
# | value_loss         | 0.00192  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.347    |
# | fps                | 92       |
# | nupdates           | 6200     |
# | policy_entropy     | 0.353    |
# | total_timesteps    | 31000    |
# | value_loss         | 0.0159   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 92       |
# | nupdates           | 6300     |
# | policy_entropy     | 0.168    |
# | total_timesteps    | 31500    |
# | value_loss         | 0.00248  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.834    |
# | fps                | 92       |
# | nupdates           | 6400     |
# | policy_entropy     | 0.422    |
# | total_timesteps    | 32000    |
# | value_loss         | 9.57e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 93       |
# | nupdates           | 6500     |
# | policy_entropy     | 0.178    |
# | total_timesteps    | 32500    |
# | value_loss         | 0.0011   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.936    |
# | fps                | 93       |
# | nupdates           | 6600     |
# | policy_entropy     | 0.379    |
# | total_timesteps    | 33000    |
# | value_loss         | 3.91e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 93       |
# | nupdates           | 6700     |
# | policy_entropy     | 0.176    |
# | total_timesteps    | 33500    |
# | value_loss         | 6.63e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.697    |
# | fps                | 93       |
# | nupdates           | 6800     |
# | policy_entropy     | 0.34     |
# | total_timesteps    | 34000    |
# | value_loss         | 0.000397 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.284    |
# | fps                | 93       |
# | nupdates           | 6900     |
# | policy_entropy     | 0.204    |
# | total_timesteps    | 34500    |
# | value_loss         | 9.41e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.507    |
# | fps                | 93       |
# | nupdates           | 7000     |
# | policy_entropy     | 0.314    |
# | total_timesteps    | 35000    |
# | value_loss         | 0.000336 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.879    |
# | fps                | 93       |
# | nupdates           | 7100     |
# | policy_entropy     | 0.18     |
# | total_timesteps    | 35500    |
# | value_loss         | 1.26e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.727    |
# | fps                | 93       |
# | nupdates           | 7200     |
# | policy_entropy     | 0.413    |
# | total_timesteps    | 36000    |
# | value_loss         | 0.000603 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0949  |
# | fps                | 94       |
# | nupdates           | 7300     |
# | policy_entropy     | 0.0594   |
# | total_timesteps    | 36500    |
# | value_loss         | 0.000146 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.68     |
# | fps                | 94       |
# | nupdates           | 7400     |
# | policy_entropy     | 0.416    |
# | total_timesteps    | 37000    |
# | value_loss         | 0.000363 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 94       |
# | nupdates           | 7500     |
# | policy_entropy     | 0.0631   |
# | total_timesteps    | 37500    |
# | value_loss         | 7.03e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 94       |
# | nupdates           | 7600     |
# | policy_entropy     | 0.374    |
# | total_timesteps    | 38000    |
# | value_loss         | 0.00167  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.898    |
# | fps                | 94       |
# | nupdates           | 7700     |
# | policy_entropy     | 0.175    |
# | total_timesteps    | 38500    |
# | value_loss         | 0.000599 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 94       |
# | nupdates           | 7800     |
# | policy_entropy     | 0.353    |
# | total_timesteps    | 39000    |
# | value_loss         | 0.00135  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 94       |
# | nupdates           | 7900     |
# | policy_entropy     | 0.198    |
# | total_timesteps    | 39500    |
# | value_loss         | 0.000175 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 95       |
# | nupdates           | 8000     |
# | policy_entropy     | 0.234    |
# | total_timesteps    | 40000    |
# | value_loss         | 7.16e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.768    |
# | fps                | 95       |
# | nupdates           | 8100     |
# | policy_entropy     | 0.205    |
# | total_timesteps    | 40500    |
# | value_loss         | 0.00217  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 95       |
# | nupdates           | 8200     |
# | policy_entropy     | 0.148    |
# | total_timesteps    | 41000    |
# | value_loss         | 0.000572 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.818    |
# | fps                | 95       |
# | nupdates           | 8300     |
# | policy_entropy     | 0.315    |
# | total_timesteps    | 41500    |
# | value_loss         | 0.000205 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 95       |
# | nupdates           | 8400     |
# | policy_entropy     | 0.0463   |
# | total_timesteps    | 42000    |
# | value_loss         | 0.000145 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.94    |
# | fps                | 95       |
# | nupdates           | 8500     |
# | policy_entropy     | 0.36     |
# | total_timesteps    | 42500    |
# | value_loss         | 0.00277  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.888    |
# | fps                | 95       |
# | nupdates           | 8600     |
# | policy_entropy     | 0.0487   |
# | total_timesteps    | 43000    |
# | value_loss         | 0.000264 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 95       |
# | nupdates           | 8700     |
# | policy_entropy     | 0.223    |
# | total_timesteps    | 43500    |
# | value_loss         | 5.43e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.881    |
# | fps                | 95       |
# | nupdates           | 8800     |
# | policy_entropy     | 0.0464   |
# | total_timesteps    | 44000    |
# | value_loss         | 0.000227 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.913    |
# | fps                | 96       |
# | nupdates           | 8900     |
# | policy_entropy     | 0.238    |
# | total_timesteps    | 44500    |
# | value_loss         | 2.37e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.964    |
# | fps                | 96       |
# | nupdates           | 9000     |
# | policy_entropy     | 0.0262   |
# | total_timesteps    | 45000    |
# | value_loss         | 0.000267 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 96       |
# | nupdates           | 9100     |
# | policy_entropy     | 0.234    |
# | total_timesteps    | 45500    |
# | value_loss         | 6.03e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.956    |
# | fps                | 96       |
# | nupdates           | 9200     |
# | policy_entropy     | 0.00454  |
# | total_timesteps    | 46000    |
# | value_loss         | 1.04e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 96       |
# | nupdates           | 9300     |
# | policy_entropy     | 0.256    |
# | total_timesteps    | 46500    |
# | value_loss         | 3.64e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.974    |
# | fps                | 96       |
# | nupdates           | 9400     |
# | policy_entropy     | 0.016    |
# | total_timesteps    | 47000    |
# | value_loss         | 6.35e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 96       |
# | nupdates           | 9500     |
# | policy_entropy     | 0.228    |
# | total_timesteps    | 47500    |
# | value_loss         | 0.00473  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.933    |
# | fps                | 96       |
# | nupdates           | 9600     |
# | policy_entropy     | 0.0181   |
# | total_timesteps    | 48000    |
# | value_loss         | 2.1e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 96       |
# | nupdates           | 9700     |
# | policy_entropy     | 0.329    |
# | total_timesteps    | 48500    |
# | value_loss         | 0.000543 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 96       |
# | nupdates           | 9800     |
# | policy_entropy     | 0.154    |
# | total_timesteps    | 49000    |
# | value_loss         | 0.000118 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.684    |
# | fps                | 97       |
# | nupdates           | 9900     |
# | policy_entropy     | 0.382    |
# | total_timesteps    | 49500    |
# | value_loss         | 0.000169 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 97       |
# | nupdates           | 10000    |
# | policy_entropy     | 0.314    |
# | total_timesteps    | 50000    |
# | value_loss         | 0.000451 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.893    |
# | fps                | 97       |
# | nupdates           | 10100    |
# | policy_entropy     | 0.302    |
# | total_timesteps    | 50500    |
# | value_loss         | 8.69e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 97       |
# | nupdates           | 10200    |
# | policy_entropy     | 0.291    |
# | total_timesteps    | 51000    |
# | value_loss         | 3.22e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 97       |
# | nupdates           | 10300    |
# | policy_entropy     | 0.2      |
# | total_timesteps    | 51500    |
# | value_loss         | 0.000609 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 97       |
# | nupdates           | 10400    |
# | policy_entropy     | 0.282    |
# | total_timesteps    | 52000    |
# | value_loss         | 2.4e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.967    |
# | fps                | 97       |
# | nupdates           | 10500    |
# | policy_entropy     | 0.219    |
# | total_timesteps    | 52500    |
# | value_loss         | 0.000242 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.646    |
# | fps                | 97       |
# | nupdates           | 10600    |
# | policy_entropy     | 0.287    |
# | total_timesteps    | 53000    |
# | value_loss         | 5.54e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.459    |
# | fps                | 97       |
# | nupdates           | 10700    |
# | policy_entropy     | 0.279    |
# | total_timesteps    | 53500    |
# | value_loss         | 0.000789 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.707    |
# | fps                | 97       |
# | nupdates           | 10800    |
# | policy_entropy     | 0.157    |
# | total_timesteps    | 54000    |
# | value_loss         | 7.42e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.909    |
# | fps                | 97       |
# | nupdates           | 10900    |
# | policy_entropy     | 0.379    |
# | total_timesteps    | 54500    |
# | value_loss         | 5.31e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.489    |
# | fps                | 97       |
# | nupdates           | 11000    |
# | policy_entropy     | 0.0285   |
# | total_timesteps    | 55000    |
# | value_loss         | 0.00763  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.886    |
# | fps                | 97       |
# | nupdates           | 11100    |
# | policy_entropy     | 0.416    |
# | total_timesteps    | 55500    |
# | value_loss         | 0.000547 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 98       |
# | nupdates           | 11200    |
# | policy_entropy     | 0.034    |
# | total_timesteps    | 56000    |
# | value_loss         | 1.81e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 98       |
# | nupdates           | 11300    |
# | policy_entropy     | 0.337    |
# | total_timesteps    | 56500    |
# | value_loss         | 0.000695 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.986    |
# | fps                | 98       |
# | nupdates           | 11400    |
# | policy_entropy     | 0.0952   |
# | total_timesteps    | 57000    |
# | value_loss         | 0.000139 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 98       |
# | nupdates           | 11500    |
# | policy_entropy     | 0.32     |
# | total_timesteps    | 57500    |
# | value_loss         | 0.0022   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 98       |
# | nupdates           | 11600    |
# | policy_entropy     | 0.149    |
# | total_timesteps    | 58000    |
# | value_loss         | 4.18e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 98       |
# | nupdates           | 11700    |
# | policy_entropy     | 0.182    |
# | total_timesteps    | 58500    |
# | value_loss         | 0.000206 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.984    |
# | fps                | 98       |
# | nupdates           | 11800    |
# | policy_entropy     | 0.147    |
# | total_timesteps    | 59000    |
# | value_loss         | 7.43e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 98       |
# | nupdates           | 11900    |
# | policy_entropy     | 0.0932   |
# | total_timesteps    | 59500    |
# | value_loss         | 0.000412 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.19     |
# | fps                | 98       |
# | nupdates           | 12000    |
# | policy_entropy     | 0.264    |
# | total_timesteps    | 60000    |
# | value_loss         | 0.00119  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 98       |
# | nupdates           | 12100    |
# | policy_entropy     | 0.0358   |
# | total_timesteps    | 60500    |
# | value_loss         | 1.32e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 98       |
# | nupdates           | 12200    |
# | policy_entropy     | 0.303    |
# | total_timesteps    | 61000    |
# | value_loss         | 2.17e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 98       |
# | nupdates           | 12300    |
# | policy_entropy     | 0.034    |
# | total_timesteps    | 61500    |
# | value_loss         | 2.79e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.832    |
# | fps                | 98       |
# | nupdates           | 12400    |
# | policy_entropy     | 0.251    |
# | total_timesteps    | 62000    |
# | value_loss         | 7.38e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 98       |
# | nupdates           | 12500    |
# | policy_entropy     | 0.0347   |
# | total_timesteps    | 62500    |
# | value_loss         | 8.47e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.918    |
# | fps                | 98       |
# | nupdates           | 12600    |
# | policy_entropy     | 0.235    |
# | total_timesteps    | 63000    |
# | value_loss         | 5.47e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 98       |
# | nupdates           | 12700    |
# | policy_entropy     | 0.0319   |
# | total_timesteps    | 63500    |
# | value_loss         | 0.000172 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 98       |
# | nupdates           | 12800    |
# | policy_entropy     | 0.236    |
# | total_timesteps    | 64000    |
# | value_loss         | 1.07e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 98       |
# | nupdates           | 12900    |
# | policy_entropy     | 0.0135   |
# | total_timesteps    | 64500    |
# | value_loss         | 4.86e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 99       |
# | nupdates           | 13000    |
# | policy_entropy     | 0.243    |
# | total_timesteps    | 65000    |
# | value_loss         | 0.000102 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 99       |
# | nupdates           | 13100    |
# | policy_entropy     | 0.0137   |
# | total_timesteps    | 65500    |
# | value_loss         | 1.62e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 13200    |
# | policy_entropy     | 0.218    |
# | total_timesteps    | 66000    |
# | value_loss         | 3.27e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.973    |
# | fps                | 99       |
# | nupdates           | 13300    |
# | policy_entropy     | 0.0208   |
# | total_timesteps    | 66500    |
# | value_loss         | 8.42e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 99       |
# | nupdates           | 13400    |
# | policy_entropy     | 0.347    |
# | total_timesteps    | 67000    |
# | value_loss         | 0.000216 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 13500    |
# | policy_entropy     | 0.149    |
# | total_timesteps    | 67500    |
# | value_loss         | 1.15e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -145     |
# | fps                | 99       |
# | nupdates           | 13600    |
# | policy_entropy     | 0.36     |
# | total_timesteps    | 68000    |
# | value_loss         | 0.00171  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 13700    |
# | policy_entropy     | 0.269    |
# | total_timesteps    | 68500    |
# | value_loss         | 2.13e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.944    |
# | fps                | 99       |
# | nupdates           | 13800    |
# | policy_entropy     | 0.312    |
# | total_timesteps    | 69000    |
# | value_loss         | 4.53e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 13900    |
# | policy_entropy     | 0.293    |
# | total_timesteps    | 69500    |
# | value_loss         | 6.18e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.491    |
# | fps                | 99       |
# | nupdates           | 14000    |
# | policy_entropy     | 0.301    |
# | total_timesteps    | 70000    |
# | value_loss         | 0.0013   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 99       |
# | nupdates           | 14100    |
# | policy_entropy     | 0.294    |
# | total_timesteps    | 70500    |
# | value_loss         | 0.000293 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.875    |
# | fps                | 99       |
# | nupdates           | 14200    |
# | policy_entropy     | 0.244    |
# | total_timesteps    | 71000    |
# | value_loss         | 0.000118 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.937    |
# | fps                | 99       |
# | nupdates           | 14300    |
# | policy_entropy     | 0.28     |
# | total_timesteps    | 71500    |
# | value_loss         | 6.07e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.46e+03 |
# | fps                | 99        |
# | nupdates           | 14400     |
# | policy_entropy     | 0.273     |
# | total_timesteps    | 72000     |
# | value_loss         | 0.000733  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.889    |
# | fps                | 99       |
# | nupdates           | 14500    |
# | policy_entropy     | 0.161    |
# | total_timesteps    | 72500    |
# | value_loss         | 1.03e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.581    |
# | fps                | 99       |
# | nupdates           | 14600    |
# | policy_entropy     | 0.424    |
# | total_timesteps    | 73000    |
# | value_loss         | 0.000664 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.727    |
# | fps                | 99       |
# | nupdates           | 14700    |
# | policy_entropy     | 0.0509   |
# | total_timesteps    | 73500    |
# | value_loss         | 5.97e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.884    |
# | fps                | 99       |
# | nupdates           | 14800    |
# | policy_entropy     | 0.431    |
# | total_timesteps    | 74000    |
# | value_loss         | 0.00119  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 99       |
# | nupdates           | 14900    |
# | policy_entropy     | 0.0348   |
# | total_timesteps    | 74500    |
# | value_loss         | 3.57e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 99       |
# | nupdates           | 15000    |
# | policy_entropy     | 0.296    |
# | total_timesteps    | 75000    |
# | value_loss         | 0.00194  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.05    |
# | fps                | 99       |
# | nupdates           | 15100    |
# | policy_entropy     | 0.109    |
# | total_timesteps    | 75500    |
# | value_loss         | 0.0189   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 15200    |
# | policy_entropy     | 0.275    |
# | total_timesteps    | 76000    |
# | value_loss         | 8.6e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 99       |
# | nupdates           | 15300    |
# | policy_entropy     | 0.0889   |
# | total_timesteps    | 76500    |
# | value_loss         | 9.84e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 15400    |
# | policy_entropy     | 0.184    |
# | total_timesteps    | 77000    |
# | value_loss         | 0.000219 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 99       |
# | nupdates           | 15500    |
# | policy_entropy     | 0.14     |
# | total_timesteps    | 77500    |
# | value_loss         | 1.95e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 99       |
# | nupdates           | 15600    |
# | policy_entropy     | 0.079    |
# | total_timesteps    | 78000    |
# | value_loss         | 0.000375 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 99       |
# | nupdates           | 15700    |
# | policy_entropy     | 0.263    |
# | total_timesteps    | 78500    |
# | value_loss         | 6.4e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 99       |
# | nupdates           | 15800    |
# | policy_entropy     | 0.0141   |
# | total_timesteps    | 79000    |
# | value_loss         | 5.28e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 99       |
# | nupdates           | 15900    |
# | policy_entropy     | 0.305    |
# | total_timesteps    | 79500    |
# | value_loss         | 0.000122 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 99       |
# | nupdates           | 16000    |
# | policy_entropy     | 0.0138   |
# | total_timesteps    | 80000    |
# | value_loss         | 1.73e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 99       |
# | nupdates           | 16100    |
# | policy_entropy     | 0.243    |
# | total_timesteps    | 80500    |
# | value_loss         | 7.4e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 99       |
# | nupdates           | 16200    |
# | policy_entropy     | 0.0109   |
# | total_timesteps    | 81000    |
# | value_loss         | 9.63e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.941    |
# | fps                | 99       |
# | nupdates           | 16300    |
# | policy_entropy     | 0.237    |
# | total_timesteps    | 81500    |
# | value_loss         | 0.000153 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 99       |
# | nupdates           | 16400    |
# | policy_entropy     | 0.0108   |
# | total_timesteps    | 82000    |
# | value_loss         | 3.29e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 100      |
# | nupdates           | 16500    |
# | policy_entropy     | 0.245    |
# | total_timesteps    | 82500    |
# | value_loss         | 0.000127 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 100      |
# | nupdates           | 16600    |
# | policy_entropy     | 0.00259  |
# | total_timesteps    | 83000    |
# | value_loss         | 1.73e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 100      |
# | nupdates           | 16700    |
# | policy_entropy     | 0.209    |
# | total_timesteps    | 83500    |
# | value_loss         | 0.000124 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.903    |
# | fps                | 100      |
# | nupdates           | 16800    |
# | policy_entropy     | 0.004    |
# | total_timesteps    | 84000    |
# | value_loss         | 2.75e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 100      |
# | nupdates           | 16900    |
# | policy_entropy     | 0.2      |
# | total_timesteps    | 84500    |
# | value_loss         | 0.000337 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.937    |
# | fps                | 101      |
# | nupdates           | 17000    |
# | policy_entropy     | 0.00781  |
# | total_timesteps    | 85000    |
# | value_loss         | 9.19e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 101      |
# | nupdates           | 17100    |
# | policy_entropy     | 0.245    |
# | total_timesteps    | 85500    |
# | value_loss         | 7.79e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 101      |
# | nupdates           | 17200    |
# | policy_entropy     | 0.145    |
# | total_timesteps    | 86000    |
# | value_loss         | 8.5e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 101      |
# | nupdates           | 17300    |
# | policy_entropy     | 0.225    |
# | total_timesteps    | 86500    |
# | value_loss         | 3.13e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 101      |
# | nupdates           | 17400    |
# | policy_entropy     | 0.277    |
# | total_timesteps    | 87000    |
# | value_loss         | 0.000196 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.249    |
# | fps                | 102      |
# | nupdates           | 17500    |
# | policy_entropy     | 0.283    |
# | total_timesteps    | 87500    |
# | value_loss         | 0.000285 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 102      |
# | nupdates           | 17600    |
# | policy_entropy     | 0.289    |
# | total_timesteps    | 88000    |
# | value_loss         | 8.25e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 102      |
# | nupdates           | 17700    |
# | policy_entropy     | 0.202    |
# | total_timesteps    | 88500    |
# | value_loss         | 0.00036  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 102      |
# | nupdates           | 17800    |
# | policy_entropy     | 0.291    |
# | total_timesteps    | 89000    |
# | value_loss         | 2.91e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.138    |
# | fps                | 102      |
# | nupdates           | 17900    |
# | policy_entropy     | 0.18     |
# | total_timesteps    | 89500    |
# | value_loss         | 0.000326 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.893    |
# | fps                | 103      |
# | nupdates           | 18000    |
# | policy_entropy     | 0.294    |
# | total_timesteps    | 90000    |
# | value_loss         | 2.94e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.918    |
# | fps                | 103      |
# | nupdates           | 18100    |
# | policy_entropy     | 0.296    |
# | total_timesteps    | 90500    |
# | value_loss         | 5.52e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.61    |
# | fps                | 103      |
# | nupdates           | 18200    |
# | policy_entropy     | 0.142    |
# | total_timesteps    | 91000    |
# | value_loss         | 0.000795 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 103      |
# | nupdates           | 18300    |
# | policy_entropy     | 0.375    |
# | total_timesteps    | 91500    |
# | value_loss         | 2.59e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.968    |
# | fps                | 103      |
# | nupdates           | 18400    |
# | policy_entropy     | 0.0199   |
# | total_timesteps    | 92000    |
# | value_loss         | 2.1e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.884    |
# | fps                | 103      |
# | nupdates           | 18500    |
# | policy_entropy     | 0.449    |
# | total_timesteps    | 92500    |
# | value_loss         | 4.65e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 104      |
# | nupdates           | 18600    |
# | policy_entropy     | 0.0318   |
# | total_timesteps    | 93000    |
# | value_loss         | 1.87e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 104      |
# | nupdates           | 18700    |
# | policy_entropy     | 0.336    |
# | total_timesteps    | 93500    |
# | value_loss         | 0.000345 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 104      |
# | nupdates           | 18800    |
# | policy_entropy     | 0.0645   |
# | total_timesteps    | 94000    |
# | value_loss         | 6.53e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 104      |
# | nupdates           | 18900    |
# | policy_entropy     | 0.355    |
# | total_timesteps    | 94500    |
# | value_loss         | 8.15e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 104      |
# | nupdates           | 19000    |
# | policy_entropy     | 0.0597   |
# | total_timesteps    | 95000    |
# | value_loss         | 3.76e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 104      |
# | nupdates           | 19100    |
# | policy_entropy     | 0.178    |
# | total_timesteps    | 95500    |
# | value_loss         | 0.000615 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 105      |
# | nupdates           | 19200    |
# | policy_entropy     | 0.0868   |
# | total_timesteps    | 96000    |
# | value_loss         | 0.000143 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 105      |
# | nupdates           | 19300    |
# | policy_entropy     | 0.119    |
# | total_timesteps    | 96500    |
# | value_loss         | 0.000112 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.513    |
# | fps                | 105      |
# | nupdates           | 19400    |
# | policy_entropy     | 0.234    |
# | total_timesteps    | 97000    |
# | value_loss         | 0.000742 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 105      |
# | nupdates           | 19500    |
# | policy_entropy     | 0.00866  |
# | total_timesteps    | 97500    |
# | value_loss         | 3.24e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 105      |
# | nupdates           | 19600    |
# | policy_entropy     | 0.255    |
# | total_timesteps    | 98000    |
# | value_loss         | 4.32e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 105      |
# | nupdates           | 19700    |
# | policy_entropy     | 0.00855  |
# | total_timesteps    | 98500    |
# | value_loss         | 9.69e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 106      |
# | nupdates           | 19800    |
# | policy_entropy     | 0.239    |
# | total_timesteps    | 99000    |
# | value_loss         | 5.99e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 106      |
# | nupdates           | 19900    |
# | policy_entropy     | 0.00742  |
# | total_timesteps    | 99500    |
# | value_loss         | 7.66e-05 |
# ---------------------------------

# %% [markdown]
# ## Testing the model

# %%
# env = gym.make('stocks-v0',df=df,frame_bound=(5,2000),window_size=5)
env = MyCustomEnv(df=df,window_size=12,frame_bound=(180,240))
obs = env.reset()
while True:
    obs = obs[np.newaxis, ...] #taking observation
    #reshaping using np.newaxis to be able to work with nnon-vectorized environment 
    action,_states = model.predict(obs) #rather than using random action we are using our model and predicting which action it shoudl take
    obs,reward,done,info = env.step(action) 
    if done:
        print("info",info)
        print("action is",action)
        break

# %% [markdown]
# # Visualising our model

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()

plt.savefig("RPower",dpi=100)
plt.show()

# %%
! git add "RPowerStocksTrader.ipynb"
! git commit -m "Reliance Power stocks"
! git push origin main
