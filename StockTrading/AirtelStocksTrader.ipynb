# %% [markdown]
# ## Importing the dependecies

# %%
# ! pip install tensorflow-gpu==1.15.0 tensorflow==1.15.0 stable-baselines gym-anytrading gym

# %%
# gym stuff
import gym
import gym_anytrading

#Stable baselines
from stable_baselines.common.vec_env import DummyVecEnv #it is a wrapper
from stable_baselines import A2C #A2C is RL algorithm

#processing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %% [markdown]
# ## MarketWatch GME data

# %%
df = pd.read_csv('data/BHARTIARTL.NS.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       250 non-null    float64
#  2   High       250 non-null    float64
#  3   Low        250 non-null    float64
#  4   Close      250 non-null    float64
#  5   Adj Close  250 non-null    float64
#  6   Volume     250 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# # Coverting date to datetimeformat

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   Open       250 non-null    float64
#  2   High       250 non-null    float64
#  3   Low        250 non-null    float64
#  4   Close      250 non-null    float64
#  5   Adj Close  250 non-null    float64
#  6   Volume     250 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 13.9 KB

# %%
# df['Open'] = df['Open'].apply(lambda x: float(x.replace(",","")))

# %%
# df['High'] = df['High'].apply(lambda x: float(x.replace(",","")))

# %%
# df['Low'] = df['Low'].apply(lambda x: float(x.replace(",","")))

# %%
# df['Close'] = df['Close'].apply(lambda x: float(x.replace(",","")))

# %%
#Sorting the data from oldest to newest
df.sort_values('Date',ascending=True,inplace=True)
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-06-18  564.250000  572.900024  558.200012  560.900024  558.893066
# 1 2020-06-19  561.900024  578.200012  561.000000  572.500000  570.451538
# 2 2020-06-22  575.799988  588.000000  570.400024  581.049988  578.970947
# 3 2020-06-23  581.049988  584.599976  574.349976  578.799988  576.728943
# 4 2020-06-24  581.000000  582.000000  555.000000  557.349976  555.355713
#
#        Volume
# 0  19329677.0
# 1  41152081.0
# 2  12715764.0
# 3   9761566.0
# 4  12387239.0

# %%
# Set index as date
df.set_index('Date',inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-18  564.250000  572.900024  558.200012  560.900024  558.893066
# 2020-06-19  561.900024  578.200012  561.000000  572.500000  570.451538
# 2020-06-22  575.799988  588.000000  570.400024  581.049988  578.970947
# 2020-06-23  581.049988  584.599976  574.349976  578.799988  576.728943
# 2020-06-24  581.000000  582.000000  555.000000  557.349976  555.355713
#
#                 Volume
# Date
# 2020-06-18  19329677.0
# 2020-06-19  41152081.0
# 2020-06-22  12715764.0
# 2020-06-23   9761566.0
# 2020-06-24  12387239.0

# %%
env = gym.make('stocks-v0',df=df,frame_bound=(5,200),window_size=5)
#window_size = how many previous timestep data our bot is going to have for referce to make a trade
#frame_bound = specifies how much data we want to pass through our environment we are gonna start at 5th time step 
#and go all the way to the hundredth time_step .

# %% [markdown]
# `Note since our window size is 5 and frame_bound's initial value is also 5 our env.prices will start from very first day i.e. 05/25/2021`
#
# `And if our frame bound's initial value is changed to (10,100) from (5,100) our env.prices will start from 5 day later i.e. 05/18/2021`

# %%
print("(env.prices\n",env.prices)
print("env.signal_features\n",env.signal_features) #it shows price and change in price from previous timestep
# Out:
# (env.prices
#  [560.900024 572.5      581.049988 578.799988 557.349976 559.
#  560.400024 567.099976 559.849976 560.150024 558.450012 581.450012
#  576.599976 567.150024 561.299988 568.650024 574.700012 586.799988
#  589.349976 563.599976 562.75     566.75     575.75     567.75
#  569.150024 567.200012 559.450012 559.5      564.599976 566.200012
#  552.700012 554.849976 547.349976 549.       558.950012 555.299988
#  560.799988 558.849976 551.099976 547.700012 535.349976 528.599976
#  521.400024 526.299988 535.849976 525.549988 520.25     526.900024
#  [ 6.08849976e+02  9.50000000e+00]
#  [ 6.00599976e+02 -8.25000000e+00]
#  [ 5.81099976e+02 -1.95000000e+01]
#  [ 5.97299988e+02  1.62000120e+01]
#  [ 5.98950012e+02  1.65002400e+00]
#  [ 5.90200012e+02 -8.75000000e+00]
#  [ 5.98099976e+02  7.89996400e+00]
#  [ 5.86250000e+02 -1.18499760e+01]
#  [ 5.93700012e+02  7.45001200e+00]
#  [ 5.93950012e+02  2.50000000e-01]
#  [ 5.93849976e+02 -1.00036000e-01]
#  [ 5.89049988e+02 -4.79998800e+00]
#  [ 5.81349976e+02 -7.70001200e+00]
#  [ 5.70299988e+02 -1.10499880e+01]
#  [ 5.65549988e+02 -4.75000000e+00]
#  [ 5.72950012e+02  7.40002400e+00]
#  [ 5.79150024e+02  6.20001200e+00]
#  [ 5.56299988e+02 -2.28500360e+01]
#  [ 5.32200012e+02 -2.40999760e+01]
#  [ 5.41200012e+02  9.00000000e+00]
#  [ 5.46299988e+02  5.09997600e+00]
#  [ 5.39599976e+02 -6.70001200e+00]
#  [ 5.32799988e+02 -6.79998800e+00]
#  [ 5.25700012e+02 -7.09997600e+00]
#  [ 5.21750000e+02 -3.95001200e+00]
#  [ 5.25849976e+02  4.09997600e+00]
#  [ 5.24200012e+02 -1.64996400e+00]
#  [ 5.22849976e+02 -1.35003600e+00]
#  [ 5.29299988e+02  6.45001200e+00]
#  [ 5.22900024e+02 -6.39996400e+00]
#  [ 5.27200012e+02  4.29998800e+00]
#  [ 5.29950012e+02  2.75000000e+00]
#  [ 5.28000000e+02 -1.95001200e+00]
#  [ 5.29250000e+02  1.25000000e+00]
#  [ 5.23650024e+02 -5.59997600e+00]
#  [ 5.07750000e+02 -1.59000240e+01]
#  [ 5.22500000e+02  1.47500000e+01]
#  [ 5.21500000e+02 -1.00000000e+00]
#  [ 5.17299988e+02 -4.20001200e+00]
#  [ 5.20799988e+02  3.50000000e+00]]

# %% [markdown]
# ## Build Environment

# %%
#Taking random steps/ Testing the env
state = env.reset() #it allows us to get initial state
while True:
    action = env.action_space.sample() #looping through each index and taking random action
    n_state,reward,done,info = env.step(action) #applying action to our environment. and storing them in variables
    if done: 
        print(f" n_state\n{n_state}\n reward\n{reward}\n  done\n{done}\n  info\n{info}\n ")
        
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
# plt.savefig("Initial Images\Initial Airtel",dpi=100)
plt.show()
# Out:
#  n_state
# [[523.650024  -5.599976]
#  [507.75     -15.900024]
#  [522.5       14.75    ]
#  [521.5       -1.      ]
#  [517.299988  -4.200012]]
#  reward
# 0
#   done
# True
#   info
# {'total_reward': 117.60000600000001, 'total_profit': 0.5912461638412979, 'position': 1}

# %%
env.action_space #we have only 2 action buy and sell
# Out:
# Discrete(2)

# %% [markdown]
# # 3.1 - Add Custom Indicators

# %% [markdown]
# ### 3.1.1 Install and Import New Dependencies
#
# ##### `We'll  be using finta`

# %%
# !pip install finta
from gym_anytrading.envs import StocksEnv
from finta import TA #Technical Analysis lirary

# %% [markdown]
# ### 3.1.2 - Fix Volume Column

# %%
# print(df.dtypes)
# #inintially volume is object/string changing it to float
# df['Volume'] = df['Volume'].apply(lambda x: float(x.replace(",","")))

# # (x.replace",","") stripping/removing all the commas

# %% [markdown]
# ### 3.1.3 Calculate SMA,RSI and OBV

# %%
df['SMA'] = TA.SMA(df,12) #we want 12 period simple movimg average
df['RSI'] = TA.RSI(df) #relative strength index
df['OBV'] = TA.OBV(df) #on balance volume inndicator

df.fillna(0,inplace=True) #removing NAN with 0

# %%
df.head(15)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-18  564.250000  572.900024  558.200012  560.900024  558.893066
# 2020-06-19  561.900024  578.200012  561.000000  572.500000  570.451538
# 2020-06-22  575.799988  588.000000  570.400024  581.049988  578.970947
# 2020-06-23  581.049988  584.599976  574.349976  578.799988  576.728943
# 2020-06-24  581.000000  582.000000  555.000000  557.349976  555.355713
# 2020-06-25  553.900024  563.700012  550.000000  559.000000  556.999817
# 2020-06-26  560.000000  566.400024  557.150024  560.400024  558.394836
# 2020-06-29  558.900024  568.950012  551.200012  567.099976  565.070801
# 2020-06-30  572.000000  577.000000  557.400024  559.849976  557.846741
# 2020-07-01  575.000000  575.000000  558.299988  560.150024  558.145752
# 2020-07-02  564.799988  567.000000  557.599976  558.450012  556.451782
# 2020-07-03  561.799988  583.450012  560.599976  581.450012  579.369507
# 2020-07-06  587.599976  589.299988  575.049988  576.599976  574.536804
# 2020-07-07  579.000000  582.599976  566.049988  567.150024  565.120667
# 2020-07-08  572.000000  574.000000  559.000000  561.299988  559.291565
#
#                 Volume         SMA         RSI         OBV
# Date
# 2020-06-18  19329677.0    0.000000    0.000000         0.0
# 2020-06-19  41152081.0    0.000000  100.000000  41152081.0
# 2020-06-22  12715764.0    0.000000  100.000000  53867845.0
# 2020-06-23   9761566.0    0.000000   88.856584  44106279.0
# 2020-06-24  12387239.0    0.000000   41.443180  31719040.0
# 2020-06-25  15588791.0    0.000000   43.922036  47307831.0
# 2020-06-26  11108837.0    0.000000   46.010434  58416668.0
# 2020-06-29  12920390.0    0.000000   54.704067  71337058.0
# 2020-06-30  12939125.0    0.000000   46.060867  58397933.0
# 2020-07-01  13638591.0    0.000000   46.438047  72036524.0
# 2020-07-02  13541452.0    0.000000   44.537761  58495072.0
# 2020-07-03  20618770.0  566.416667   65.253988  79113842.0
# 2020-07-06  15817653.0  567.724996   60.151721  63296189.0
# 2020-07-07  12524299.0  567.279165   51.673692  50771890.0
# 2020-07-08   9404733.0  565.633331   47.235287  41367157.0

# %% [markdown]
# #### 3.1.4 Create New Environment

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size #here env.frame_bound[0] = 5
    end = env.frame_bound[1] # here env.frame_bound[1] = 250
    prices = env.df.loc[:,'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:,['Low','Volume','SMA','RSI','OBV']].to_numpy()[start:end] 
    return prices,signal_features

# %%
#Creating custom env
class MyCustomEnv(StocksEnv): #inheritence is happening here
    _process_data = add_signals
    
env2 = MyCustomEnv(df=df,window_size=12,frame_bound=(12,50)) #creating instance

# %%
env2.prices
# Out:
# array([558.200012, 561.      , 570.400024, 574.349976, 555.      ,
#        550.      , 557.150024, 551.200012, 557.400024, 558.299988,
#        557.599976, 560.599976, 575.049988, 566.049988, 559.      ,
#          3.62341041e+01,  1.09717370e+07],
#        [ 5.16000000e+02,  2.18349480e+07,  5.38920822e+02,
#          3.40919972e+01, -1.08632110e+07],
#        [ 5.08200012e+02,  2.91667950e+07,  5.36554159e+02,
#          3.89674832e+01,  1.83035840e+07],
#        [ 5.26000000e+02,  1.95154690e+07,  5.33874995e+02,
#          4.02207110e+01,  3.78190530e+07],
#        [ 5.12000000e+02,  2.59007110e+07,  5.30179164e+02,
#          3.41199865e+01,  1.19183420e+07]])

# %% [markdown]
# ## Building Environment and Training

# %%
#Wrapping our environment inside of dummyvenEnv
env_maker = lambda:env2
# env_maker = lambda:gym.make('stocks-v0',df=df, frame_bound=(5,100),window_size=5)

env  = DummyVecEnv([env_maker])

#we are creatinng env_makr function and putting it inside DummyvecEnv wrapper

# %%
#Start Training
model = A2C('MlpLstmPolicy',env,verbose=1) #multilayer-perceptron -lstm policy
model.learn(total_timesteps=100000) #starting to learn
# Out:
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\policies.py:420: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\Sumit\anaconda3\envs\tf1.5\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | 0.00986  |
# | fps                | 2        |
# | nupdates           | 1        |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 5        |
# | value_loss         | 19.3     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000619 |
# | fps                | 50        |
# | nupdates           | 100       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 500       |
# | value_loss         | 87.4      |
# ----------------------------------
# ---------------------------------
# | explained_variance | -390     |
# | fps                | 52       |
# | nupdates           | 200      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1000     |
# | value_loss         | 0.0263   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00157  |
# | fps                | 61       |
# | nupdates           | 300      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1500     |
# | value_loss         | 152      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0153   |
# | fps                | 67       |
# | nupdates           | 400      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 2000     |
# | value_loss         | 232      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000231 |
# | fps                | 72       |
# | nupdates           | 500      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 2500     |
# | value_loss         | 117      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0363   |
# | fps                | 78       |
# | nupdates           | 600      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 3000     |
# | value_loss         | 94.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0841  |
# | fps                | 83       |
# | nupdates           | 700      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 3500     |
# | value_loss         | 0.00693  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.214    |
# | fps                | 87       |
# | nupdates           | 800      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 4000     |
# | value_loss         | 0.752    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0758   |
# | fps                | 91       |
# | nupdates           | 900      |
# | policy_entropy     | 0.653    |
# | total_timesteps    | 4500     |
# | value_loss         | 0.0873   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0666  |
# | fps                | 95       |
# | nupdates           | 1000     |
# | policy_entropy     | 0.464    |
# | total_timesteps    | 5000     |
# | value_loss         | 20.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -281     |
# | fps                | 97       |
# | nupdates           | 1100     |
# | policy_entropy     | 0.0817   |
# | total_timesteps    | 5500     |
# | value_loss         | 0.000702 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.71e+04 |
# | fps                | 98        |
# | nupdates           | 1200      |
# | policy_entropy     | 0.0548    |
# | total_timesteps    | 6000      |
# | value_loss         | 0.00181   |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2e+03   |
# | fps                | 99       |
# | nupdates           | 1300     |
# | policy_entropy     | 0.0289   |
# | total_timesteps    | 6500     |
# | value_loss         | 0.000439 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.56e+03 |
# | fps                | 101       |
# | nupdates           | 1400      |
# | policy_entropy     | 0.00839   |
# | total_timesteps    | 7000      |
# | value_loss         | 0.00035   |
# ----------------------------------
# ---------------------------------
# | explained_variance | -10.8    |
# | fps                | 103      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.00352  |
# | total_timesteps    | 7500     |
# | value_loss         | 6.07e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.28e+04 |
# | fps                | 104       |
# | nupdates           | 1600      |
# | policy_entropy     | 0.00508   |
# | total_timesteps    | 8000      |
# | value_loss         | 0.000127  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -155     |
# | fps                | 105      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.00727  |
# | total_timesteps    | 8500     |
# | value_loss         | 0.000138 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -810     |
# | fps                | 106      |
# | nupdates           | 1800     |
# | policy_entropy     | 0.00969  |
# | total_timesteps    | 9000     |
# | value_loss         | 6.24e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -720     |
# | fps                | 108      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.00906  |
# | total_timesteps    | 9500     |
# | value_loss         | 2.28e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.92e+03 |
# | fps                | 110       |
# | nupdates           | 2000      |
# | policy_entropy     | 0.00268   |
# | total_timesteps    | 10000     |
# | value_loss         | 9.48e-05  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -8.24e+03 |
# | fps                | 111       |
# | nupdates           | 2100      |
# | policy_entropy     | 0.00222   |
# | total_timesteps    | 10500     |
# | value_loss         | 4.52e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -18      |
# | fps                | 112      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.0019   |
# | total_timesteps    | 11000    |
# | value_loss         | 0.000105 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.1e+04 |
# | fps                | 113      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.00157  |
# | total_timesteps    | 11500    |
# | value_loss         | 5.54e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.72e+03 |
# | fps                | 114       |
# | nupdates           | 2400      |
# | policy_entropy     | 0.002     |
# | total_timesteps    | 12000     |
# | value_loss         | 2e-05     |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.27e+03 |
# | fps                | 114       |
# | nupdates           | 2500      |
# | policy_entropy     | 0.00189   |
# | total_timesteps    | 12500     |
# | value_loss         | 2.71e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -1.88    |
# | fps                | 115      |
# | nupdates           | 2600     |
# | policy_entropy     | 0.00129  |
# | total_timesteps    | 13000    |
# | value_loss         | 5.66e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.15e+03 |
# | fps                | 116       |
# | nupdates           | 2700      |
# | policy_entropy     | 0.00142   |
# | total_timesteps    | 13500     |
# | value_loss         | 9.94e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.64e+03 |
# | fps                | 117       |
# | nupdates           | 2800      |
# | policy_entropy     | 0.00122   |
# | total_timesteps    | 14000     |
# | value_loss         | 1.02e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -819     |
# | fps                | 118      |
# | nupdates           | 2900     |
# | policy_entropy     | 0.000984 |
# | total_timesteps    | 14500    |
# | value_loss         | 3.95e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -144     |
# | fps                | 118      |
# | nupdates           | 3000     |
# | policy_entropy     | 0.000625 |
# | total_timesteps    | 15000    |
# | value_loss         | 1.06e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -121     |
# | fps                | 118      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.00133  |
# | total_timesteps    | 15500    |
# | value_loss         | 1.11e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -28.9    |
# | fps                | 119      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.000598 |
# | total_timesteps    | 16000    |
# | value_loss         | 2.4e-05  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.69e+05 |
# | fps                | 120       |
# | nupdates           | 3300      |
# | policy_entropy     | 0.00177   |
# | total_timesteps    | 16500     |
# | value_loss         | 8.82e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.11e+03 |
# | fps                | 121       |
# | nupdates           | 3400      |
# | policy_entropy     | 0.00059   |
# | total_timesteps    | 17000     |
# | value_loss         | 8.44e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.14e+03 |
# | fps                | 122       |
# | nupdates           | 3500      |
# | policy_entropy     | 0.00286   |
# | total_timesteps    | 17500     |
# | value_loss         | 3.21e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.43e+03 |
# | fps                | 122       |
# | nupdates           | 3600      |
# | policy_entropy     | 0.000644  |
# | total_timesteps    | 18000     |
# | value_loss         | 3.98e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 123      |
# | nupdates           | 3700     |
# | policy_entropy     | 0.00515  |
# | total_timesteps    | 18500    |
# | value_loss         | 1.31e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.49e+03 |
# | fps                | 124       |
# | nupdates           | 3800      |
# | policy_entropy     | 0.00069   |
# | total_timesteps    | 19000     |
# | value_loss         | 8.47e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.62    |
# | fps                | 124      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.0305   |
# | total_timesteps    | 19500    |
# | value_loss         | 6.3e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -751     |
# | fps                | 125      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.000421 |
# | total_timesteps    | 20000    |
# | value_loss         | 7.9e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.68    |
# | fps                | 125      |
# | nupdates           | 4100     |
# | policy_entropy     | 0.0274   |
# | total_timesteps    | 20500    |
# | value_loss         | 8.05e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.94    |
# | fps                | 126      |
# | nupdates           | 4200     |
# | policy_entropy     | 0.000266 |
# | total_timesteps    | 21000    |
# | value_loss         | 0.000226 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.71    |
# | fps                | 127      |
# | nupdates           | 4300     |
# | policy_entropy     | 0.0232   |
# | total_timesteps    | 21500    |
# | value_loss         | 2.44e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -529     |
# | fps                | 127      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.00029  |
# | total_timesteps    | 22000    |
# | value_loss         | 3.3e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.24    |
# | fps                | 127      |
# | nupdates           | 4500     |
# | policy_entropy     | 0.0237   |
# | total_timesteps    | 22500    |
# | value_loss         | 2.28e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.67e+03 |
# | fps                | 127       |
# | nupdates           | 4600      |
# | policy_entropy     | 0.00032   |
# | total_timesteps    | 23000     |
# | value_loss         | 8.42e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -767     |
# | fps                | 127      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.017    |
# | total_timesteps    | 23500    |
# | value_loss         | 5.31e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -783     |
# | fps                | 127      |
# | nupdates           | 4800     |
# | policy_entropy     | 0.000164 |
# | total_timesteps    | 24000    |
# | value_loss         | 1.85e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -661     |
# | fps                | 126      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.00156  |
# | total_timesteps    | 24500    |
# | value_loss         | 5.46e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -160     |
# | fps                | 126      |
# | nupdates           | 5000     |
# | policy_entropy     | 0.000171 |
# | total_timesteps    | 25000    |
# | value_loss         | 8.87e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.84e+03 |
# | fps                | 125       |
# | nupdates           | 5100      |
# | policy_entropy     | 0.000514  |
# | total_timesteps    | 25500     |
# | value_loss         | 7.11e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.09e+03 |
# | fps                | 124       |
# | nupdates           | 5200      |
# | policy_entropy     | 0.000174  |
# | total_timesteps    | 26000     |
# | value_loss         | 2.71e-05  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.31e+03 |
# | fps                | 123       |
# | nupdates           | 5300      |
# | policy_entropy     | 0.000332  |
# | total_timesteps    | 26500     |
# | value_loss         | 6.84e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -89.4    |
# | fps                | 123      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.000184 |
# | total_timesteps    | 27000    |
# | value_loss         | 2.31e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -391     |
# | fps                | 123      |
# | nupdates           | 5500     |
# | policy_entropy     | 0.000289 |
# | total_timesteps    | 27500    |
# | value_loss         | 3.1e-06  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.66e+05 |
# | fps                | 122       |
# | nupdates           | 5600      |
# | policy_entropy     | 0.000187  |
# | total_timesteps    | 28000     |
# | value_loss         | 1.66e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -89.2    |
# | fps                | 122      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.000281 |
# | total_timesteps    | 28500    |
# | value_loss         | 1.01e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -571     |
# | fps                | 121      |
# | nupdates           | 5800     |
# | policy_entropy     | 0.000199 |
# | total_timesteps    | 29000    |
# | value_loss         | 2.2e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -362     |
# | fps                | 121      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.000291 |
# | total_timesteps    | 29500    |
# | value_loss         | 6.94e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -211     |
# | fps                | 121      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.000215 |
# | total_timesteps    | 30000    |
# | value_loss         | 1.64e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -213     |
# | fps                | 122      |
# | nupdates           | 6100     |
# | policy_entropy     | 0.000287 |
# | total_timesteps    | 30500    |
# | value_loss         | 1.48e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.83e+04 |
# | fps                | 122       |
# | nupdates           | 6200      |
# | policy_entropy     | 0.000244  |
# | total_timesteps    | 31000     |
# | value_loss         | 8.78e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.31e+04 |
# | fps                | 122       |
# | nupdates           | 6300      |
# | policy_entropy     | 0.000285  |
# | total_timesteps    | 31500     |
# | value_loss         | 1.86e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -434     |
# | fps                | 123      |
# | nupdates           | 6400     |
# | policy_entropy     | 0.000286 |
# | total_timesteps    | 32000    |
# | value_loss         | 8.2e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -596     |
# | fps                | 123      |
# | nupdates           | 6500     |
# | policy_entropy     | 0.00026  |
# | total_timesteps    | 32500    |
# | value_loss         | 1.24e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.08e+03 |
# | fps                | 123       |
# | nupdates           | 6600      |
# | policy_entropy     | 0.000375  |
# | total_timesteps    | 33000     |
# | value_loss         | 4.35e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -13.2    |
# | fps                | 124      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.000112 |
# | total_timesteps    | 33500    |
# | value_loss         | 5.71e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -145     |
# | fps                | 124      |
# | nupdates           | 6800     |
# | policy_entropy     | 0.000261 |
# | total_timesteps    | 34000    |
# | value_loss         | 4.95e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.81e+03 |
# | fps                | 124       |
# | nupdates           | 6900      |
# | policy_entropy     | 0.000102  |
# | total_timesteps    | 34500     |
# | value_loss         | 1.03e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -367     |
# | fps                | 125      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.000343 |
# | total_timesteps    | 35000    |
# | value_loss         | 4.67e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -153     |
# | fps                | 125      |
# | nupdates           | 7100     |
# | policy_entropy     | 9.55e-05 |
# | total_timesteps    | 35500    |
# | value_loss         | 3.72e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.04e+04 |
# | fps                | 125       |
# | nupdates           | 7200      |
# | policy_entropy     | 0.00053   |
# | total_timesteps    | 36000     |
# | value_loss         | 1.49e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.24e+03 |
# | fps                | 125       |
# | nupdates           | 7300      |
# | policy_entropy     | 9.84e-05  |
# | total_timesteps    | 36500     |
# | value_loss         | 2.17e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 125      |
# | nupdates           | 7400     |
# | policy_entropy     | 0.00101  |
# | total_timesteps    | 37000    |
# | value_loss         | 2.32e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -227     |
# | fps                | 124      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.000102 |
# | total_timesteps    | 37500    |
# | value_loss         | 2.61e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.13    |
# | fps                | 125      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.012    |
# | total_timesteps    | 38000    |
# | value_loss         | 0.0243   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -718     |
# | fps                | 124      |
# | nupdates           | 7700     |
# | policy_entropy     | 4.98e-05 |
# | total_timesteps    | 38500    |
# | value_loss         | 2.4e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.1     |
# | fps                | 124      |
# | nupdates           | 7800     |
# | policy_entropy     | 0.0128   |
# | total_timesteps    | 39000    |
# | value_loss         | 2.38e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.68e+05 |
# | fps                | 125       |
# | nupdates           | 7900      |
# | policy_entropy     | 5.38e-05  |
# | total_timesteps    | 39500     |
# | value_loss         | 3.97e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00954  |
# | fps                | 125      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.013    |
# | total_timesteps    | 40000    |
# | value_loss         | 7.2e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -73.7    |
# | fps                | 125      |
# | nupdates           | 8100     |
# | policy_entropy     | 5.72e-05 |
# | total_timesteps    | 40500    |
# | value_loss         | 1.05e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.67    |
# | fps                | 125      |
# | nupdates           | 8200     |
# | policy_entropy     | 0.0132   |
# | total_timesteps    | 41000    |
# | value_loss         | 7.6e-06  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.73e+05 |
# | fps                | 125       |
# | nupdates           | 8300      |
# | policy_entropy     | 6.21e-05  |
# | total_timesteps    | 41500     |
# | value_loss         | 4.21e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -237     |
# | fps                | 125      |
# | nupdates           | 8400     |
# | policy_entropy     | 0.0131   |
# | total_timesteps    | 42000    |
# | value_loss         | 8.11e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -396     |
# | fps                | 125      |
# | nupdates           | 8500     |
# | policy_entropy     | 6.6e-05  |
# | total_timesteps    | 42500    |
# | value_loss         | 1.7e-05  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.88e+04 |
# | fps                | 125       |
# | nupdates           | 8600      |
# | policy_entropy     | 0.000866  |
# | total_timesteps    | 43000     |
# | value_loss         | 3.17e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -58.8    |
# | fps                | 125      |
# | nupdates           | 8700     |
# | policy_entropy     | 6.84e-05 |
# | total_timesteps    | 43500    |
# | value_loss         | 5.2e-06  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.89e+03 |
# | fps                | 125       |
# | nupdates           | 8800      |
# | policy_entropy     | 0.000239  |
# | total_timesteps    | 44000     |
# | value_loss         | 4.18e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.15e+05 |
# | fps                | 125       |
# | nupdates           | 8900      |
# | policy_entropy     | 6.87e-05  |
# | total_timesteps    | 44500     |
# | value_loss         | 7.11e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.88e+03 |
# | fps                | 126       |
# | nupdates           | 9000      |
# | policy_entropy     | 0.000142  |
# | total_timesteps    | 45000     |
# | value_loss         | 5.81e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -75.5    |
# | fps                | 126      |
# | nupdates           | 9100     |
# | policy_entropy     | 7.17e-05 |
# | total_timesteps    | 45500    |
# | value_loss         | 1.13e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -97.4    |
# | fps                | 126      |
# | nupdates           | 9200     |
# | policy_entropy     | 0.000119 |
# | total_timesteps    | 46000    |
# | value_loss         | 5.7e-07  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.97e+05 |
# | fps                | 126       |
# | nupdates           | 9300      |
# | policy_entropy     | 7.18e-05  |
# | total_timesteps    | 46500     |
# | value_loss         | 6.83e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -14.1    |
# | fps                | 126      |
# | nupdates           | 9400     |
# | policy_entropy     | 0.000113 |
# | total_timesteps    | 47000    |
# | value_loss         | 6.28e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -223     |
# | fps                | 127      |
# | nupdates           | 9500     |
# | policy_entropy     | 7.59e-05 |
# | total_timesteps    | 47500    |
# | value_loss         | 1.1e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -19.9    |
# | fps                | 127      |
# | nupdates           | 9600     |
# | policy_entropy     | 0.000115 |
# | total_timesteps    | 48000    |
# | value_loss         | 3.12e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -53.7    |
# | fps                | 127      |
# | nupdates           | 9700     |
# | policy_entropy     | 8.24e-05 |
# | total_timesteps    | 48500    |
# | value_loss         | 1.33e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -81.8    |
# | fps                | 127      |
# | nupdates           | 9800     |
# | policy_entropy     | 0.000112 |
# | total_timesteps    | 49000    |
# | value_loss         | 6.17e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.83e+03 |
# | fps                | 127       |
# | nupdates           | 9900      |
# | policy_entropy     | 9.44e-05  |
# | total_timesteps    | 49500     |
# | value_loss         | 3.59e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.66e+04 |
# | fps                | 128       |
# | nupdates           | 10000     |
# | policy_entropy     | 0.000109  |
# | total_timesteps    | 50000     |
# | value_loss         | 1.55e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -170     |
# | fps                | 128      |
# | nupdates           | 10100    |
# | policy_entropy     | 0.000112 |
# | total_timesteps    | 50500    |
# | value_loss         | 4.48e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -121     |
# | fps                | 128      |
# | nupdates           | 10200    |
# | policy_entropy     | 9.71e-05 |
# | total_timesteps    | 51000    |
# | value_loss         | 9.58e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.69e+03 |
# | fps                | 129       |
# | nupdates           | 10300     |
# | policy_entropy     | 0.00015   |
# | total_timesteps    | 51500     |
# | value_loss         | 3.93e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -20.8    |
# | fps                | 129      |
# | nupdates           | 10400    |
# | policy_entropy     | 8.67e-05 |
# | total_timesteps    | 52000    |
# | value_loss         | 7.8e-07  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -69.5    |
# | fps                | 130      |
# | nupdates           | 10500    |
# | policy_entropy     | 0.000204 |
# | total_timesteps    | 52500    |
# | value_loss         | 4.12e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -26.9    |
# | fps                | 130      |
# | nupdates           | 10600    |
# | policy_entropy     | 7.86e-05 |
# | total_timesteps    | 53000    |
# | value_loss         | 5.9e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -106     |
# | fps                | 131      |
# | nupdates           | 10700    |
# | policy_entropy     | 0.000269 |
# | total_timesteps    | 53500    |
# | value_loss         | 4.5e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -172     |
# | fps                | 131      |
# | nupdates           | 10800    |
# | policy_entropy     | 7.36e-05 |
# | total_timesteps    | 54000    |
# | value_loss         | 1.95e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -485     |
# | fps                | 132      |
# | nupdates           | 10900    |
# | policy_entropy     | 0.000419 |
# | total_timesteps    | 54500    |
# | value_loss         | 4.18e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -212     |
# | fps                | 132      |
# | nupdates           | 11000    |
# | policy_entropy     | 7.56e-05 |
# | total_timesteps    | 55000    |
# | value_loss         | 1.21e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 133      |
# | nupdates           | 11100    |
# | policy_entropy     | 0.000821 |
# | total_timesteps    | 55500    |
# | value_loss         | 3.22e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -147     |
# | fps                | 133      |
# | nupdates           | 11200    |
# | policy_entropy     | 7.82e-05 |
# | total_timesteps    | 56000    |
# | value_loss         | 1.01e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.11    |
# | fps                | 134      |
# | nupdates           | 11300    |
# | policy_entropy     | 0.0166   |
# | total_timesteps    | 56500    |
# | value_loss         | 1.45e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -23.2    |
# | fps                | 134      |
# | nupdates           | 11400    |
# | policy_entropy     | 8.57e-05 |
# | total_timesteps    | 57000    |
# | value_loss         | 4.61e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.879   |
# | fps                | 135      |
# | nupdates           | 11500    |
# | policy_entropy     | 0.0179   |
# | total_timesteps    | 57500    |
# | value_loss         | 2.31e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.64e+04 |
# | fps                | 135       |
# | nupdates           | 11600     |
# | policy_entropy     | 9.31e-05  |
# | total_timesteps    | 58000     |
# | value_loss         | 2.85e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.633   |
# | fps                | 136      |
# | nupdates           | 11700    |
# | policy_entropy     | 0.0183   |
# | total_timesteps    | 58500    |
# | value_loss         | 7.06e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -96.7    |
# | fps                | 136      |
# | nupdates           | 11800    |
# | policy_entropy     | 9.99e-05 |
# | total_timesteps    | 59000    |
# | value_loss         | 9.25e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.96    |
# | fps                | 137      |
# | nupdates           | 11900    |
# | policy_entropy     | 0.0187   |
# | total_timesteps    | 59500    |
# | value_loss         | 7.09e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -456     |
# | fps                | 137      |
# | nupdates           | 12000    |
# | policy_entropy     | 0.000109 |
# | total_timesteps    | 60000    |
# | value_loss         | 4.42e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -400     |
# | fps                | 138      |
# | nupdates           | 12100    |
# | policy_entropy     | 0.0187   |
# | total_timesteps    | 60500    |
# | value_loss         | 5.9e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.5e+03 |
# | fps                | 138      |
# | nupdates           | 12200    |
# | policy_entropy     | 0.000118 |
# | total_timesteps    | 61000    |
# | value_loss         | 1.51e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2e+03   |
# | fps                | 138      |
# | nupdates           | 12300    |
# | policy_entropy     | 0.00146  |
# | total_timesteps    | 61500    |
# | value_loss         | 4.4e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -79.8    |
# | fps                | 139      |
# | nupdates           | 12400    |
# | policy_entropy     | 0.000123 |
# | total_timesteps    | 62000    |
# | value_loss         | 7.64e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.48e+03 |
# | fps                | 139       |
# | nupdates           | 12500     |
# | policy_entropy     | 0.000429  |
# | total_timesteps    | 62500     |
# | value_loss         | 3.54e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.45e+05 |
# | fps                | 140       |
# | nupdates           | 12600     |
# | policy_entropy     | 0.000125  |
# | total_timesteps    | 63000     |
# | value_loss         | 5.61e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -757     |
# | fps                | 140      |
# | nupdates           | 12700    |
# | policy_entropy     | 0.000262 |
# | total_timesteps    | 63500    |
# | value_loss         | 1.85e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -99      |
# | fps                | 140      |
# | nupdates           | 12800    |
# | policy_entropy     | 0.000132 |
# | total_timesteps    | 64000    |
# | value_loss         | 6.25e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -39.3    |
# | fps                | 141      |
# | nupdates           | 12900    |
# | policy_entropy     | 0.000222 |
# | total_timesteps    | 64500    |
# | value_loss         | 2.74e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.93e+03 |
# | fps                | 141       |
# | nupdates           | 13000     |
# | policy_entropy     | 0.000133  |
# | total_timesteps    | 65000     |
# | value_loss         | 5.12e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.95    |
# | fps                | 142      |
# | nupdates           | 13100    |
# | policy_entropy     | 0.000214 |
# | total_timesteps    | 65500    |
# | value_loss         | 4.83e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -245     |
# | fps                | 142      |
# | nupdates           | 13200    |
# | policy_entropy     | 0.000143 |
# | total_timesteps    | 66000    |
# | value_loss         | 6.02e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -20.5    |
# | fps                | 143      |
# | nupdates           | 13300    |
# | policy_entropy     | 0.000222 |
# | total_timesteps    | 66500    |
# | value_loss         | 1.6e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -65.6    |
# | fps                | 143      |
# | nupdates           | 13400    |
# | policy_entropy     | 0.000156 |
# | total_timesteps    | 67000    |
# | value_loss         | 4.13e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -147     |
# | fps                | 144      |
# | nupdates           | 13500    |
# | policy_entropy     | 0.000219 |
# | total_timesteps    | 67500    |
# | value_loss         | 3.72e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -975     |
# | fps                | 144      |
# | nupdates           | 13600    |
# | policy_entropy     | 0.00018  |
# | total_timesteps    | 68000    |
# | value_loss         | 1.69e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -135     |
# | fps                | 144      |
# | nupdates           | 13700    |
# | policy_entropy     | 0.000217 |
# | total_timesteps    | 68500    |
# | value_loss         | 1.95e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -96.4    |
# | fps                | 145      |
# | nupdates           | 13800    |
# | policy_entropy     | 0.000213 |
# | total_timesteps    | 69000    |
# | value_loss         | 2.99e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -138     |
# | fps                | 145      |
# | nupdates           | 13900    |
# | policy_entropy     | 0.000197 |
# | total_timesteps    | 69500    |
# | value_loss         | 7.68e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.5e+04 |
# | fps                | 146      |
# | nupdates           | 14000    |
# | policy_entropy     | 0.000283 |
# | total_timesteps    | 70000    |
# | value_loss         | 2.15e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -37.7    |
# | fps                | 146      |
# | nupdates           | 14100    |
# | policy_entropy     | 0.000178 |
# | total_timesteps    | 70500    |
# | value_loss         | 7.2e-07  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -64.1    |
# | fps                | 146      |
# | nupdates           | 14200    |
# | policy_entropy     | 0.000381 |
# | total_timesteps    | 71000    |
# | value_loss         | 3.34e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -44.6    |
# | fps                | 147      |
# | nupdates           | 14300    |
# | policy_entropy     | 0.000163 |
# | total_timesteps    | 71500    |
# | value_loss         | 4.69e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -142     |
# | fps                | 147      |
# | nupdates           | 14400    |
# | policy_entropy     | 0.000501 |
# | total_timesteps    | 72000    |
# | value_loss         | 2.26e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -385     |
# | fps                | 148      |
# | nupdates           | 14500    |
# | policy_entropy     | 0.000155 |
# | total_timesteps    | 72500    |
# | value_loss         | 1.61e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -207     |
# | fps                | 148      |
# | nupdates           | 14600    |
# | policy_entropy     | 0.000768 |
# | total_timesteps    | 73000    |
# | value_loss         | 4.89e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -78      |
# | fps                | 149      |
# | nupdates           | 14700    |
# | policy_entropy     | 0.000161 |
# | total_timesteps    | 73500    |
# | value_loss         | 9.05e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 149      |
# | nupdates           | 14800    |
# | policy_entropy     | 0.00145  |
# | total_timesteps    | 74000    |
# | value_loss         | 2.2e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -152     |
# | fps                | 149      |
# | nupdates           | 14900    |
# | policy_entropy     | 0.000168 |
# | total_timesteps    | 74500    |
# | value_loss         | 7.61e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.346   |
# | fps                | 150      |
# | nupdates           | 15000    |
# | policy_entropy     | 0.0262   |
# | total_timesteps    | 75000    |
# | value_loss         | 3.1e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -33      |
# | fps                | 150      |
# | nupdates           | 15100    |
# | policy_entropy     | 0.000188 |
# | total_timesteps    | 75500    |
# | value_loss         | 2.64e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.949   |
# | fps                | 150      |
# | nupdates           | 15200    |
# | policy_entropy     | 0.0288   |
# | total_timesteps    | 76000    |
# | value_loss         | 1.05e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -9.22e+03 |
# | fps                | 151       |
# | nupdates           | 15300     |
# | policy_entropy     | 0.000207  |
# | total_timesteps    | 76500     |
# | value_loss         | 1.64e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.811   |
# | fps                | 151      |
# | nupdates           | 15400    |
# | policy_entropy     | 0.0299   |
# | total_timesteps    | 77000    |
# | value_loss         | 7.05e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -99      |
# | fps                | 152      |
# | nupdates           | 15500    |
# | policy_entropy     | 0.000226 |
# | total_timesteps    | 77500    |
# | value_loss         | 6.32e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.72    |
# | fps                | 152      |
# | nupdates           | 15600    |
# | policy_entropy     | 0.0308   |
# | total_timesteps    | 78000    |
# | value_loss         | 6.21e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -191     |
# | fps                | 152      |
# | nupdates           | 15700    |
# | policy_entropy     | 0.000252 |
# | total_timesteps    | 78500    |
# | value_loss         | 3.75e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -780     |
# | fps                | 153      |
# | nupdates           | 15800    |
# | policy_entropy     | 0.0311   |
# | total_timesteps    | 79000    |
# | value_loss         | 3.57e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.69e+03 |
# | fps                | 153       |
# | nupdates           | 15900     |
# | policy_entropy     | 0.000277  |
# | total_timesteps    | 79500     |
# | value_loss         | 1.17e-05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.1e+03 |
# | fps                | 153      |
# | nupdates           | 16000    |
# | policy_entropy     | 0.00315  |
# | total_timesteps    | 80000    |
# | value_loss         | 3.96e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -143     |
# | fps                | 154      |
# | nupdates           | 16100    |
# | policy_entropy     | 0.000294 |
# | total_timesteps    | 80500    |
# | value_loss         | 5.86e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.25e+04 |
# | fps                | 154       |
# | nupdates           | 16200     |
# | policy_entropy     | 0.00102   |
# | total_timesteps    | 81000     |
# | value_loss         | 2.94e-06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.29e+05 |
# | fps                | 154       |
# | nupdates           | 16300     |
# | policy_entropy     | 0.000305  |
# | total_timesteps    | 81500     |
# | value_loss         | 3.78e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -632     |
# | fps                | 155      |
# | nupdates           | 16400    |
# | policy_entropy     | 0.000655 |
# | total_timesteps    | 82000    |
# | value_loss         | 1.38e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -138     |
# | fps                | 155      |
# | nupdates           | 16500    |
# | policy_entropy     | 0.000331 |
# | total_timesteps    | 82500    |
# | value_loss         | 3.74e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -61.2    |
# | fps                | 155      |
# | nupdates           | 16600    |
# | policy_entropy     | 0.000571 |
# | total_timesteps    | 83000    |
# | value_loss         | 3.18e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.01e+03 |
# | fps                | 156       |
# | nupdates           | 16700     |
# | policy_entropy     | 0.000342  |
# | total_timesteps    | 83500     |
# | value_loss         | 4e-06     |
# ----------------------------------
# ---------------------------------
# | explained_variance | -19.6    |
# | fps                | 156      |
# | nupdates           | 16800    |
# | policy_entropy     | 0.000569 |
# | total_timesteps    | 84000    |
# | value_loss         | 2.77e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.29e+04 |
# | fps                | 156       |
# | nupdates           | 16900     |
# | policy_entropy     | 0.000207  |
# | total_timesteps    | 84500     |
# | value_loss         | 3.26e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -253     |
# | fps                | 157      |
# | nupdates           | 17000    |
# | policy_entropy     | 0.00034  |
# | total_timesteps    | 85000    |
# | value_loss         | 1.26e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -74.6    |
# | fps                | 157      |
# | nupdates           | 17100    |
# | policy_entropy     | 0.000227 |
# | total_timesteps    | 85500    |
# | value_loss         | 1.44e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -208     |
# | fps                | 157      |
# | nupdates           | 17200    |
# | policy_entropy     | 0.000344 |
# | total_timesteps    | 86000    |
# | value_loss         | 6.09e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.07e+03 |
# | fps                | 158       |
# | nupdates           | 17300     |
# | policy_entropy     | 0.000264  |
# | total_timesteps    | 86500     |
# | value_loss         | 1.54e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -71.1    |
# | fps                | 158      |
# | nupdates           | 17400    |
# | policy_entropy     | 0.000353 |
# | total_timesteps    | 87000    |
# | value_loss         | 1.67e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -101     |
# | fps                | 158      |
# | nupdates           | 17500    |
# | policy_entropy     | 0.000314 |
# | total_timesteps    | 87500    |
# | value_loss         | 1.88e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -76.4    |
# | fps                | 159      |
# | nupdates           | 17600    |
# | policy_entropy     | 0.000331 |
# | total_timesteps    | 88000    |
# | value_loss         | 8.13e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.77e+03 |
# | fps                | 159       |
# | nupdates           | 17700     |
# | policy_entropy     | 0.00041   |
# | total_timesteps    | 88500     |
# | value_loss         | 1.1e-06   |
# ----------------------------------
# ---------------------------------
# | explained_variance | -88.7    |
# | fps                | 159      |
# | nupdates           | 17800    |
# | policy_entropy     | 0.000308 |
# | total_timesteps    | 89000    |
# | value_loss         | 5.75e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -83.3    |
# | fps                | 159      |
# | nupdates           | 17900    |
# | policy_entropy     | 0.000539 |
# | total_timesteps    | 89500    |
# | value_loss         | 1.56e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -79.3    |
# | fps                | 160      |
# | nupdates           | 18000    |
# | policy_entropy     | 0.00029  |
# | total_timesteps    | 90000    |
# | value_loss         | 3.4e-06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -210     |
# | fps                | 160      |
# | nupdates           | 18100    |
# | policy_entropy     | 0.000689 |
# | total_timesteps    | 90500    |
# | value_loss         | 1.14e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -304     |
# | fps                | 160      |
# | nupdates           | 18200    |
# | policy_entropy     | 0.000282 |
# | total_timesteps    | 91000    |
# | value_loss         | 1.21e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -156     |
# | fps                | 160      |
# | nupdates           | 18300    |
# | policy_entropy     | 0.001    |
# | total_timesteps    | 91500    |
# | value_loss         | 3.51e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -56.6    |
# | fps                | 160      |
# | nupdates           | 18400    |
# | policy_entropy     | 0.000299 |
# | total_timesteps    | 92000    |
# | value_loss         | 7.73e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 161      |
# | nupdates           | 18500    |
# | policy_entropy     | 0.00167  |
# | total_timesteps    | 92500    |
# | value_loss         | 1.61e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -129     |
# | fps                | 161      |
# | nupdates           | 18600    |
# | policy_entropy     | 0.000319 |
# | total_timesteps    | 93000    |
# | value_loss         | 6.29e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.835   |
# | fps                | 161      |
# | nupdates           | 18700    |
# | policy_entropy     | 0.0441   |
# | total_timesteps    | 93500    |
# | value_loss         | 3.26e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -49.5    |
# | fps                | 161      |
# | nupdates           | 18800    |
# | policy_entropy     | 0.000361 |
# | total_timesteps    | 94000    |
# | value_loss         | 2.14e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.7     |
# | fps                | 162      |
# | nupdates           | 18900    |
# | policy_entropy     | 0.0499   |
# | total_timesteps    | 94500    |
# | value_loss         | 6.09e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.46e+03 |
# | fps                | 162       |
# | nupdates           | 19000     |
# | policy_entropy     | 0.000406  |
# | total_timesteps    | 95000     |
# | value_loss         | 9.97e-07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -3.26    |
# | fps                | 162      |
# | nupdates           | 19100    |
# | policy_entropy     | 0.045    |
# | total_timesteps    | 95500    |
# | value_loss         | 0.000321 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -20.5    |
# | fps                | 162      |
# | nupdates           | 19200    |
# | policy_entropy     | 0.000111 |
# | total_timesteps    | 96000    |
# | value_loss         | 4.64e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.24    |
# | fps                | 162      |
# | nupdates           | 19300    |
# | policy_entropy     | 0.0322   |
# | total_timesteps    | 96500    |
# | value_loss         | 4.45e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -550     |
# | fps                | 163      |
# | nupdates           | 19400    |
# | policy_entropy     | 0.000121 |
# | total_timesteps    | 97000    |
# | value_loss         | 1.34e-06 |
# ---------------------------------

# %% [markdown]
# ## Testing the model

# %%
# env = gym.make('stocks-v0',df=df,frame_bound=(5,2000),window_size=5)
env = MyCustomEnv(df=df,window_size=12,frame_bound=(180,240))
obs = env.reset()
while True:
    obs = obs[np.newaxis, ...] #taking observation
    #reshaping using np.newaxis to be able to work with nnon-vectorized environment 
    action,_states = model.predict(obs) #rather than using random action we are using our model and predicting which action it shoudl take
    obs,reward,done,info = env.step(action) 
    if done:
        print("info",info)
        print("action is",action)
        break

# %% [markdown]
# # Visualising our model

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()

plt.savefig("Airtel2",dpi=100)
plt.show()

# %%
! git add "AirtelStocksTrader.ipynb"
! git commit -m "Airtel stocks"
! git push origin main
